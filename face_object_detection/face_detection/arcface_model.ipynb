# %% [markdown]
# **Using ArcFace For Suspect Recognition**
#
# Takes a folder of suspect images, computes the mean embedding, and matches it against a dataset of images. It uses multiple thresholds to determine matches and visualizes the results.

# %%
# https://github.com/deepinsight/insightface/tree/master/model_zoo
import insightface
from insightface.app import FaceAnalysis
import cv2
import numpy as np
import os
import shutil
import matplotlib.pyplot as plt
import time
from datetime import datetime

# === Initialize ArcFace ===
app = FaceAnalysis(name='buffalo_l')
app.prepare(ctx_id=0, det_size=(640, 640))


# === Get a Single Face Embedding ===
def get_aligned_embedding(img_path):
    img = cv2.imread(img_path)
    faces = app.get(img)
    if not faces:
        print(f"[!] No face found in {img_path}")
        return None
    embedding = faces[0].embedding
    return embedding


# === Get Mean Embedding from a Folder ===
def get_mean_embedding_from_folder(folder_path):
    embeddings = []
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        emb = get_aligned_embedding(img_path)
        if emb is not None:
            emb = emb / np.linalg.norm(emb)  # Normalize
            embeddings.append(emb)
        else:
            print(f"[!] Skipped {img_path} (no face detected)")
    if len(embeddings) == 0:
        raise ValueError("No valid embeddings found in the folder.")
    mean_emb = np.mean(embeddings, axis=0)
    mean_emb = mean_emb / np.linalg.norm(mean_emb)
    print(f"✅ Mean embedding computed from {len(embeddings)} images.")
    return mean_emb, len(embeddings)


# === Match Dataset Embeddings to Suspect ===
def match_embeddings(suspect_embedding, dataset_folder, threshold=0.5):
    matches = []
    distances = []
    processed_count = 0

    for img_name in os.listdir(dataset_folder):
        img_path = os.path.join(dataset_folder, img_name)
        target_embedding = get_aligned_embedding(img_path)
        if target_embedding is not None:
            target_embedding = target_embedding / np.linalg.norm(target_embedding)
            dist = np.linalg.norm(suspect_embedding - target_embedding)
            distances.append((img_name, dist))
            processed_count += 1
            if dist < threshold:
                print(f"[MATCH] {img_name} (Distance: {dist:.3f})")
                matches.append((img_name, dist, img_path))
            else:
                print(f"[NO MATCH] {img_name} (Distance: {dist:.3f})")
    return matches, distances, processed_count


# === Plot Distances ===
def plot_distances(distances, threshold):
    distances_sorted = sorted(distances, key=lambda x: x[1])
    labels, dists = zip(*[(x[0], x[1]) for x in distances_sorted])
    plt.figure(figsize=(10, 5))
    plt.barh(labels, dists, color='skyblue')
    plt.axvline(x=threshold, color='r', linestyle='--', label=f'Threshold ({threshold})')
    plt.xlabel('Euclidean Distance')
    plt.title('Distance of Each Dataset Image from Suspect Mean Embedding')
    plt.legend()
    plt.tight_layout()
    plt.show()


# === Copy Matched Images to Folder ===
def copy_matches(matches, source_folder, destination_folder):
    os.makedirs(destination_folder, exist_ok=True)
    for img_name, dist, _ in matches:
        src = os.path.join(source_folder, img_name)
        dst = os.path.join(destination_folder, img_name)
        shutil.copy2(src, dst)
        print(f"✅ Copied {img_name} to {destination_folder}")

# === Main Pipeline with Multiple Thresholds ===
def run_face_match_pipeline_with_thresholds(suspect_folder, dataset_folder, match_folder_base, thresholds):
    start_time = time.time()
    print(f"\n🚀 Run started at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

    # Compute the mean embedding for the suspect folder
    suspect_embedding, suspect_count = get_mean_embedding_from_folder(suspect_folder)

    for threshold in thresholds:
        print(f"\n=== Processing Threshold: {threshold} ===")
        match_folder = os.path.join(match_folder_base, f"threshold_{threshold}")
        os.makedirs(match_folder, exist_ok=True)

        # Match embeddings and process results
        matches, distances, processed_count = match_embeddings(suspect_embedding, dataset_folder, threshold=threshold)

        print("\n=== Matches Found ===")
        for match in matches:
            print(f"Image: {match[0]}, Distance: {match[1]:.3f}")

        # Plot distances and copy matches to the folder
        plot_distances(distances, threshold)
        copy_matches(matches, dataset_folder, match_folder)

    elapsed_time = time.time() - start_time

    # Print final detailed output
    print("\n=== FINAL REPORT ===")
    print(f"Thresholds used: {thresholds}")
    print(f"Total suspect images: {suspect_count}")
    print(f"Total dataset images processed: {processed_count}")
    print(f"Time used: {elapsed_time:.2f} seconds")
    print("======================")

# === Run with Multiple Thresholds ===
reference_images = '../../datasets/images/face/reference_images'               # Folder of suspect images
gallery = '../../datasets/images/face/gallery'                        # Folder of images to search
match_images = '../../datasets/images/face/matched_images'             # Base folder to save matched images
thresholds = [0.5, 0.7, 1.0, 1.2]                     # Array of thresholds for matching

run_face_match_pipeline_with_thresholds(reference_images, gallery, match_images, thresholds)

#TODO: Concurrent processing of thresholds
#TODO: Object Detection for suspect images
#TODO: Video Detection
# Out:
# D:\Interpreter\Python\Projects\ai_cyberforensics\.venv\lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:121: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\scott/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\scott/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\scott/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\scott/.insightface\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\scott/.insightface\models\buffalo_l\w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)
#
# 🚀 Run started at 2025-08-03 11:40:30
# ✅ Mean embedding computed from 6 images.
#
# === Processing Threshold: 0.5 ===
# [NO MATCH] 001_08194468.jpg (Distance: 1.299)
# [NO MATCH] 001_08212dcd.jpg (Distance: 1.435)
# [NO MATCH] 001_2288a4f6.jpg (Distance: 0.749)
# [NO MATCH] 001_504d320d.jpg (Distance: 1.399)
# [NO MATCH] 001_5992faf7.jpg (Distance: 1.408)
# [NO MATCH] 001_5ef3e95c.jpg (Distance: 1.412)
# [NO MATCH] 001_986d6c22.jpg (Distance: 1.369)
# [!] No face found in ../../datasets/images/face/gallery\001_beebcee2.jpg
# [NO MATCH] 001_cb004eea.jpg (Distance: 1.417)
# [NO MATCH] 002_078f6fe5.jpg (Distance: 1.475)
# [NO MATCH] 002_24fab375.jpg (Distance: 1.443)
# [NO MATCH] 002_331d0423.jpg (Distance: 0.690)
# [NO MATCH] 002_36285f46.jpg (Distance: 1.396)
# [NO MATCH] 002_590bb980.jpg (Distance: 1.340)
# [NO MATCH] 002_6749a2c4.jpg (Distance: 1.428)
# [NO MATCH] 002_86e8aa58.jpg (Distance: 1.272)
# [NO MATCH] 002_ea6e259d.jpg (Distance: 1.398)
# [NO MATCH] 002_f6b26479.jpg (Distance: 1.397)
# [NO MATCH] 003_0e3303fc.jpg (Distance: 1.426)
# [NO MATCH] 003_21d0aae6.jpg (Distance: 1.367)
# [NO MATCH] 003_64926b97.jpg (Distance: 0.780)
# [NO MATCH] 003_85990366.jpg (Distance: 1.297)
# [NO MATCH] 003_936c5a43.jpg (Distance: 1.518)
# [NO MATCH] 003_98a0852a.jpg (Distance: 1.400)
# [NO MATCH] 003_acb20793.jpg (Distance: 1.352)
# [NO MATCH] 003_b416eed5.jpg (Distance: 1.409)
# [NO MATCH] 003_ed3fb7b1.jpg (Distance: 1.432)
# [NO MATCH] 004_0816d969.jpg (Distance: 1.333)
# [NO MATCH] 004_18e08ab4.jpg (Distance: 0.740)
# [NO MATCH] 004_3491d187.jpg (Distance: 1.387)
# [NO MATCH] 004_78847874.jpg (Distance: 1.459)
# [NO MATCH] 004_a5881d85.jpg (Distance: 1.366)
# [NO MATCH] 004_af012af1.jpg (Distance: 1.283)
# [NO MATCH] 004_af9b4c7c.jpg (Distance: 1.480)
# [NO MATCH] 004_bb16ac65.jpg (Distance: 1.444)
# [NO MATCH] 004_dc64d954.jpg (Distance: 1.365)
# [NO MATCH] 005_0623ac96.jpg (Distance: 1.374)
# [NO MATCH] 005_1fc7405f.jpg (Distance: 1.444)
# [NO MATCH] 005_2464c583.jpg (Distance: 1.406)
# [NO MATCH] 005_37066c18.jpg (Distance: 1.497)
# [NO MATCH] 005_7fe5b764.jpg (Distance: 1.298)
# [NO MATCH] 005_93b2fce9.jpg (Distance: 1.312)
# [NO MATCH] 005_9406f32d.jpg (Distance: 0.539)
# [NO MATCH] 005_b0b4e2fa.jpg (Distance: 1.435)
# [NO MATCH] 005_dac94cfe.jpg (Distance: 1.374)
# [NO MATCH] 006_04d74e12.jpg (Distance: 1.409)
# [NO MATCH] 006_30010640.jpg (Distance: 1.275)
# [NO MATCH] 006_46519378.jpg (Distance: 1.417)
# [NO MATCH] 006_8fc31fd7.jpg (Distance: 0.829)
# [NO MATCH] 006_96ea405c.jpg (Distance: 1.442)
# [NO MATCH] 006_a28f75e7.jpg (Distance: 1.391)
# [NO MATCH] 006_bbb6978e.jpg (Distance: 1.479)
# [NO MATCH] 006_eda1948f.jpg (Distance: 1.344)
# [NO MATCH] 007_0a40d399.jpg (Distance: 1.363)
# [NO MATCH] 007_1bc0bcd6.jpg (Distance: 0.734)
# [NO MATCH] 007_572cf58c.jpg (Distance: 1.373)
# [NO MATCH] 007_5b97655c.jpg (Distance: 1.415)
# [NO MATCH] 007_6ca7c622.jpg (Distance: 1.300)
# [NO MATCH] 007_76dc423a.jpg (Distance: 1.444)
# [NO MATCH] 007_9656ae64.jpg (Distance: 1.484)
# [NO MATCH] 007_ba0aa044.jpg (Distance: 1.421)
# [NO MATCH] 008_35d1be70.jpg (Distance: 0.695)
# [NO MATCH] 008_35daa4bc.jpg (Distance: 1.319)
# [NO MATCH] 008_3bfedab8.jpg (Distance: 1.427)
# [NO MATCH] 008_4d5e67ae.jpg (Distance: 1.393)
# [NO MATCH] 008_6c01eb52.jpg (Distance: 1.359)
# [!] No face found in ../../datasets/images/face/gallery\008_74cd0628.jpg
# [!] No face found in ../../datasets/images/face/gallery\008_cdaf39e7.jpg
# [NO MATCH] 008_f9ffe0c5.jpg (Distance: 1.417)
# [NO MATCH] 009_07c15c37.jpg (Distance: 1.368)
# [NO MATCH] 009_1f22d945.jpg (Distance: 1.408)
# [NO MATCH] 009_41aa3ed9.jpg (Distance: 1.365)
# [NO MATCH] 009_474a6b2e.jpg (Distance: 1.364)
# [NO MATCH] 009_8844bacc.jpg (Distance: 1.383)
# [NO MATCH] 009_a023db5b.jpg (Distance: 1.481)
# [NO MATCH] 009_b86449f6.jpg (Distance: 1.316)
# [NO MATCH] 009_f4a38fec.jpg (Distance: 0.705)
# [NO MATCH] 010_09f6d2fe.jpg (Distance: 1.412)
# [NO MATCH] 010_18d7b27c.jpg (Distance: 1.381)
# [NO MATCH] 010_2181b5f4.jpg (Distance: 1.394)
# [NO MATCH] 010_6102c83d.jpg (Distance: 1.376)
# [NO MATCH] 010_610eea60.jpg (Distance: 0.847)
# [NO MATCH] 010_8bd7dba1.jpg (Distance: 1.470)
# [NO MATCH] 010_ce5bd8a2.jpg (Distance: 1.384)
# [NO MATCH] 011_c826a613.jpg (Distance: 0.643)
# [NO MATCH] 012_563f0843.jpg (Distance: 0.638)
# [!] No face found in ../../datasets/images/face/gallery\013_f44c68a1.jpg
# [NO MATCH] 014_68248214.jpg (Distance: 0.808)
# [NO MATCH] 015_0474556e.jpg (Distance: 0.728)
# [NO MATCH] 016_8b4d3698.jpg (Distance: 0.680)
# [NO MATCH] 017_aadefe7b.jpg (Distance: 0.768)
# [NO MATCH] 018_14e5366f.jpg (Distance: 0.926)
# [NO MATCH] 019_3eb26944.jpg (Distance: 0.791)
# [NO MATCH] 020_6b7d8470.jpg (Distance: 0.672)
# [NO MATCH] 021_9ab18f1b.jpg (Distance: 0.747)
# [NO MATCH] 022_a0763313.jpg (Distance: 0.782)
# [NO MATCH] 023_4e454f96.jpg (Distance: 0.623)
# [NO MATCH] 024_bfac5f5b.jpg (Distance: 0.827)
# [NO MATCH] 025_4f2ec7c1.jpg (Distance: 0.807)
# [NO MATCH] 026_20c41942.jpg (Distance: 0.616)
# [NO MATCH] 027_2eab41f9.jpg (Distance: 0.546)
# [NO MATCH] 028_ce59b46d.jpg (Distance: 0.665)
# [NO MATCH] 029_30aec656.jpg (Distance: 0.689)
# [NO MATCH] 030_ddacf348.jpg (Distance: 0.559)
# [NO MATCH] 031_86ed9fca.jpg (Distance: 0.586)
# [NO MATCH] 032_4b3ee537.jpg (Distance: 0.589)
# [NO MATCH] 033_ef398d45.jpg (Distance: 0.821)
# [NO MATCH] 034_52d180f0.jpg (Distance: 0.683)
# [NO MATCH] 035_2a1b8bcf.jpg (Distance: 0.663)
# [NO MATCH] 036_c93144a5.jpg (Distance: 1.002)
# [NO MATCH] 037_f2fb045b.jpg (Distance: 0.737)
# [NO MATCH] 038_081386a5.jpg (Distance: 0.689)
# [NO MATCH] 039_13af66c8.jpg (Distance: 0.679)
# [NO MATCH] 040_2e8934ea.jpg (Distance: 0.586)
# [NO MATCH] 041_6ec992c9.jpg (Distance: 0.773)
# [NO MATCH] 042_05ce6c69.jpg (Distance: 0.911)
# [NO MATCH] 043_77e393de.jpg (Distance: 0.997)
# [NO MATCH] 044_18b89b8d.jpg (Distance: 0.729)
# [NO MATCH] 045_865604b0.jpg (Distance: 0.858)
# [NO MATCH] 046_31d6a7d8.jpg (Distance: 0.800)
# [NO MATCH] 047_6c6a66d2.jpg (Distance: 0.853)
# [NO MATCH] 048_8af82c54.jpg (Distance: 0.740)
# [NO MATCH] 049_9254f6f2.jpg (Distance: 0.673)
# [NO MATCH] 050_6641bd32.jpg (Distance: 0.792)
# [NO MATCH] 100_ec9fe97f.jpg (Distance: 1.290)
# [NO MATCH] 196_08de561a.jpg (Distance: 1.375)
# [NO MATCH] 197_ed22acef.jpg (Distance: 1.427)
# [NO MATCH] 198_e056989e.jpg (Distance: 1.467)
# [NO MATCH] 199_67b0ebbd.jpg (Distance: 1.421)
# [NO MATCH] 200_d8491f8c.jpg (Distance: 1.409)
#
# === Matches Found ===
# === Processing Threshold: 0.7 ===
# [NO MATCH] 001_08194468.jpg (Distance: 1.299)
# [NO MATCH] 001_08212dcd.jpg (Distance: 1.435)
# [NO MATCH] 001_2288a4f6.jpg (Distance: 0.749)
# [NO MATCH] 001_504d320d.jpg (Distance: 1.399)
# [NO MATCH] 001_5992faf7.jpg (Distance: 1.408)
# [NO MATCH] 001_5ef3e95c.jpg (Distance: 1.412)
# [NO MATCH] 001_986d6c22.jpg (Distance: 1.369)
# [!] No face found in ../../datasets/images/face/gallery\001_beebcee2.jpg
# [NO MATCH] 001_cb004eea.jpg (Distance: 1.417)
# [NO MATCH] 002_078f6fe5.jpg (Distance: 1.475)
# [NO MATCH] 002_24fab375.jpg (Distance: 1.443)
# [MATCH] 002_331d0423.jpg (Distance: 0.690)
# [NO MATCH] 002_36285f46.jpg (Distance: 1.396)
# [NO MATCH] 002_590bb980.jpg (Distance: 1.340)
# [NO MATCH] 002_6749a2c4.jpg (Distance: 1.428)
# [NO MATCH] 002_86e8aa58.jpg (Distance: 1.272)
# [NO MATCH] 002_ea6e259d.jpg (Distance: 1.398)
# [NO MATCH] 002_f6b26479.jpg (Distance: 1.397)
# [NO MATCH] 003_0e3303fc.jpg (Distance: 1.426)
# [NO MATCH] 003_21d0aae6.jpg (Distance: 1.367)
# [NO MATCH] 003_64926b97.jpg (Distance: 0.780)
# [NO MATCH] 003_85990366.jpg (Distance: 1.297)
# [NO MATCH] 003_936c5a43.jpg (Distance: 1.518)
# [NO MATCH] 003_98a0852a.jpg (Distance: 1.400)
# [NO MATCH] 003_acb20793.jpg (Distance: 1.352)
# [NO MATCH] 003_b416eed5.jpg (Distance: 1.409)
# [NO MATCH] 003_ed3fb7b1.jpg (Distance: 1.432)
# [NO MATCH] 004_0816d969.jpg (Distance: 1.333)
# [NO MATCH] 004_18e08ab4.jpg (Distance: 0.740)
# [NO MATCH] 004_3491d187.jpg (Distance: 1.387)
# [NO MATCH] 004_78847874.jpg (Distance: 1.459)
# [NO MATCH] 004_a5881d85.jpg (Distance: 1.366)
# [NO MATCH] 004_af012af1.jpg (Distance: 1.283)
# [NO MATCH] 004_af9b4c7c.jpg (Distance: 1.480)
# [NO MATCH] 004_bb16ac65.jpg (Distance: 1.444)
# [NO MATCH] 004_dc64d954.jpg (Distance: 1.365)
# [NO MATCH] 005_0623ac96.jpg (Distance: 1.374)
# [NO MATCH] 005_1fc7405f.jpg (Distance: 1.444)
# [NO MATCH] 005_2464c583.jpg (Distance: 1.406)
# [NO MATCH] 005_37066c18.jpg (Distance: 1.497)
# [NO MATCH] 005_7fe5b764.jpg (Distance: 1.298)
# [NO MATCH] 005_93b2fce9.jpg (Distance: 1.312)
# [MATCH] 005_9406f32d.jpg (Distance: 0.539)
# [NO MATCH] 005_b0b4e2fa.jpg (Distance: 1.435)
# [NO MATCH] 005_dac94cfe.jpg (Distance: 1.374)
# [NO MATCH] 006_04d74e12.jpg (Distance: 1.409)
# [NO MATCH] 006_30010640.jpg (Distance: 1.275)
# [NO MATCH] 006_46519378.jpg (Distance: 1.417)
# [NO MATCH] 006_8fc31fd7.jpg (Distance: 0.829)
# [NO MATCH] 006_96ea405c.jpg (Distance: 1.442)
# [NO MATCH] 006_a28f75e7.jpg (Distance: 1.391)
# [NO MATCH] 006_bbb6978e.jpg (Distance: 1.479)
# [NO MATCH] 006_eda1948f.jpg (Distance: 1.344)
# [NO MATCH] 007_0a40d399.jpg (Distance: 1.363)
# [NO MATCH] 007_1bc0bcd6.jpg (Distance: 0.734)
# [NO MATCH] 007_572cf58c.jpg (Distance: 1.373)
# [NO MATCH] 007_5b97655c.jpg (Distance: 1.415)
# [NO MATCH] 007_6ca7c622.jpg (Distance: 1.300)
# [NO MATCH] 007_76dc423a.jpg (Distance: 1.444)
# [NO MATCH] 007_9656ae64.jpg (Distance: 1.484)
# [NO MATCH] 007_ba0aa044.jpg (Distance: 1.421)
# [MATCH] 008_35d1be70.jpg (Distance: 0.695)
# [NO MATCH] 008_35daa4bc.jpg (Distance: 1.319)
# [NO MATCH] 008_3bfedab8.jpg (Distance: 1.427)
# [NO MATCH] 008_4d5e67ae.jpg (Distance: 1.393)
# [NO MATCH] 008_6c01eb52.jpg (Distance: 1.359)
# [!] No face found in ../../datasets/images/face/gallery\008_74cd0628.jpg
# [!] No face found in ../../datasets/images/face/gallery\008_cdaf39e7.jpg
# [NO MATCH] 008_f9ffe0c5.jpg (Distance: 1.417)
# [NO MATCH] 009_07c15c37.jpg (Distance: 1.368)
# [NO MATCH] 009_1f22d945.jpg (Distance: 1.408)
# [NO MATCH] 009_41aa3ed9.jpg (Distance: 1.365)
# [NO MATCH] 009_474a6b2e.jpg (Distance: 1.364)
# [NO MATCH] 009_8844bacc.jpg (Distance: 1.383)
# [NO MATCH] 009_a023db5b.jpg (Distance: 1.481)
# [NO MATCH] 009_b86449f6.jpg (Distance: 1.316)
# [NO MATCH] 009_f4a38fec.jpg (Distance: 0.705)
# [NO MATCH] 010_09f6d2fe.jpg (Distance: 1.412)
# [NO MATCH] 010_18d7b27c.jpg (Distance: 1.381)
# [NO MATCH] 010_2181b5f4.jpg (Distance: 1.394)
# [NO MATCH] 010_6102c83d.jpg (Distance: 1.376)
# [NO MATCH] 010_610eea60.jpg (Distance: 0.847)
# [NO MATCH] 010_8bd7dba1.jpg (Distance: 1.470)
# [NO MATCH] 010_ce5bd8a2.jpg (Distance: 1.384)
# [MATCH] 011_c826a613.jpg (Distance: 0.643)
# [MATCH] 012_563f0843.jpg (Distance: 0.638)
# [!] No face found in ../../datasets/images/face/gallery\013_f44c68a1.jpg
# [NO MATCH] 014_68248214.jpg (Distance: 0.808)
# [NO MATCH] 015_0474556e.jpg (Distance: 0.728)
# [MATCH] 016_8b4d3698.jpg (Distance: 0.680)
# [NO MATCH] 017_aadefe7b.jpg (Distance: 0.768)
# [NO MATCH] 018_14e5366f.jpg (Distance: 0.926)
# [NO MATCH] 019_3eb26944.jpg (Distance: 0.791)
# [MATCH] 020_6b7d8470.jpg (Distance: 0.672)
# [NO MATCH] 021_9ab18f1b.jpg (Distance: 0.747)
# [NO MATCH] 022_a0763313.jpg (Distance: 0.782)
# [MATCH] 023_4e454f96.jpg (Distance: 0.623)
# [NO MATCH] 024_bfac5f5b.jpg (Distance: 0.827)
# [NO MATCH] 025_4f2ec7c1.jpg (Distance: 0.807)
# [MATCH] 026_20c41942.jpg (Distance: 0.616)
# [MATCH] 027_2eab41f9.jpg (Distance: 0.546)
# [MATCH] 028_ce59b46d.jpg (Distance: 0.665)
# [MATCH] 029_30aec656.jpg (Distance: 0.689)
# [MATCH] 030_ddacf348.jpg (Distance: 0.559)
# [MATCH] 031_86ed9fca.jpg (Distance: 0.586)
# [MATCH] 032_4b3ee537.jpg (Distance: 0.589)
# [NO MATCH] 033_ef398d45.jpg (Distance: 0.821)
# [MATCH] 034_52d180f0.jpg (Distance: 0.683)
# [MATCH] 035_2a1b8bcf.jpg (Distance: 0.663)
# [NO MATCH] 036_c93144a5.jpg (Distance: 1.002)
# [NO MATCH] 037_f2fb045b.jpg (Distance: 0.737)
# [MATCH] 038_081386a5.jpg (Distance: 0.689)
# [MATCH] 039_13af66c8.jpg (Distance: 0.679)
# [MATCH] 040_2e8934ea.jpg (Distance: 0.586)
# [NO MATCH] 041_6ec992c9.jpg (Distance: 0.773)
# [NO MATCH] 042_05ce6c69.jpg (Distance: 0.911)
# [NO MATCH] 043_77e393de.jpg (Distance: 0.997)
# [NO MATCH] 044_18b89b8d.jpg (Distance: 0.729)
# [NO MATCH] 045_865604b0.jpg (Distance: 0.858)
# [NO MATCH] 046_31d6a7d8.jpg (Distance: 0.800)
# [NO MATCH] 047_6c6a66d2.jpg (Distance: 0.853)
# [NO MATCH] 048_8af82c54.jpg (Distance: 0.740)
# [MATCH] 049_9254f6f2.jpg (Distance: 0.673)
# [NO MATCH] 050_6641bd32.jpg (Distance: 0.792)
# [NO MATCH] 100_ec9fe97f.jpg (Distance: 1.290)
# [NO MATCH] 196_08de561a.jpg (Distance: 1.375)
# [NO MATCH] 197_ed22acef.jpg (Distance: 1.427)
# [NO MATCH] 198_e056989e.jpg (Distance: 1.467)
# [NO MATCH] 199_67b0ebbd.jpg (Distance: 1.421)
# [NO MATCH] 200_d8491f8c.jpg (Distance: 1.409)
#
# === Matches Found ===
# Image: 002_331d0423.jpg, Distance: 0.690
# Image: 005_9406f32d.jpg, Distance: 0.539
# Image: 008_35d1be70.jpg, Distance: 0.695
# Image: 011_c826a613.jpg, Distance: 0.643
# Image: 012_563f0843.jpg, Distance: 0.638
# Image: 016_8b4d3698.jpg, Distance: 0.680
# Image: 020_6b7d8470.jpg, Distance: 0.672
# Image: 023_4e454f96.jpg, Distance: 0.623
# Image: 026_20c41942.jpg, Distance: 0.616
# Image: 027_2eab41f9.jpg, Distance: 0.546
# Image: 028_ce59b46d.jpg, Distance: 0.665
# Image: 029_30aec656.jpg, Distance: 0.689
# Image: 030_ddacf348.jpg, Distance: 0.559
# Image: 031_86ed9fca.jpg, Distance: 0.586
# Image: 032_4b3ee537.jpg, Distance: 0.589
# Image: 034_52d180f0.jpg, Distance: 0.683
# Image: 035_2a1b8bcf.jpg, Distance: 0.663
# Image: 038_081386a5.jpg, Distance: 0.689
# Image: 039_13af66c8.jpg, Distance: 0.679
# Image: 040_2e8934ea.jpg, Distance: 0.586
# Image: 049_9254f6f2.jpg, Distance: 0.673
# ✅ Copied 002_331d0423.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 005_9406f32d.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 008_35d1be70.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 011_c826a613.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 012_563f0843.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 016_8b4d3698.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 020_6b7d8470.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 023_4e454f96.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 026_20c41942.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 027_2eab41f9.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 028_ce59b46d.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 029_30aec656.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 030_ddacf348.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 031_86ed9fca.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 032_4b3ee537.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 034_52d180f0.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 035_2a1b8bcf.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 038_081386a5.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 039_13af66c8.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 040_2e8934ea.jpg to ../../datasets/images/face/matched_images\threshold_0.7
# ✅ Copied 049_9254f6f2.jpg to ../../datasets/images/face/matched_images\threshold_0.7
#
# === Processing Threshold: 1.0 ===
# [NO MATCH] 001_08194468.jpg (Distance: 1.299)
# [NO MATCH] 001_08212dcd.jpg (Distance: 1.435)
# [MATCH] 001_2288a4f6.jpg (Distance: 0.749)
# [NO MATCH] 001_504d320d.jpg (Distance: 1.399)
# [NO MATCH] 001_5992faf7.jpg (Distance: 1.408)
# [NO MATCH] 001_5ef3e95c.jpg (Distance: 1.412)
# [NO MATCH] 001_986d6c22.jpg (Distance: 1.369)
# [!] No face found in ../../datasets/images/face/gallery\001_beebcee2.jpg
# [NO MATCH] 001_cb004eea.jpg (Distance: 1.417)
# [NO MATCH] 002_078f6fe5.jpg (Distance: 1.475)
# [NO MATCH] 002_24fab375.jpg (Distance: 1.443)
# [MATCH] 002_331d0423.jpg (Distance: 0.690)
# [NO MATCH] 002_36285f46.jpg (Distance: 1.396)
# [NO MATCH] 002_590bb980.jpg (Distance: 1.340)
# [NO MATCH] 002_6749a2c4.jpg (Distance: 1.428)
# [NO MATCH] 002_86e8aa58.jpg (Distance: 1.272)
# [NO MATCH] 002_ea6e259d.jpg (Distance: 1.398)
# [NO MATCH] 002_f6b26479.jpg (Distance: 1.397)
# [NO MATCH] 003_0e3303fc.jpg (Distance: 1.426)
# [NO MATCH] 003_21d0aae6.jpg (Distance: 1.367)
# [MATCH] 003_64926b97.jpg (Distance: 0.780)
# [NO MATCH] 003_85990366.jpg (Distance: 1.297)
# [NO MATCH] 003_936c5a43.jpg (Distance: 1.518)
# [NO MATCH] 003_98a0852a.jpg (Distance: 1.400)
# [NO MATCH] 003_acb20793.jpg (Distance: 1.352)
# [NO MATCH] 003_b416eed5.jpg (Distance: 1.409)
# [NO MATCH] 003_ed3fb7b1.jpg (Distance: 1.432)
# [NO MATCH] 004_0816d969.jpg (Distance: 1.333)
# [MATCH] 004_18e08ab4.jpg (Distance: 0.740)
# [NO MATCH] 004_3491d187.jpg (Distance: 1.387)
# [NO MATCH] 004_78847874.jpg (Distance: 1.459)
# [NO MATCH] 004_a5881d85.jpg (Distance: 1.366)
# [NO MATCH] 004_af012af1.jpg (Distance: 1.283)
# [NO MATCH] 004_af9b4c7c.jpg (Distance: 1.480)
# [NO MATCH] 004_bb16ac65.jpg (Distance: 1.444)
# [NO MATCH] 004_dc64d954.jpg (Distance: 1.365)
# [NO MATCH] 005_0623ac96.jpg (Distance: 1.374)
# [NO MATCH] 005_1fc7405f.jpg (Distance: 1.444)
# [NO MATCH] 005_2464c583.jpg (Distance: 1.406)
# [NO MATCH] 005_37066c18.jpg (Distance: 1.497)
# [NO MATCH] 005_7fe5b764.jpg (Distance: 1.298)
# [NO MATCH] 005_93b2fce9.jpg (Distance: 1.312)
# [MATCH] 005_9406f32d.jpg (Distance: 0.539)
# [NO MATCH] 005_b0b4e2fa.jpg (Distance: 1.435)
# [NO MATCH] 005_dac94cfe.jpg (Distance: 1.374)
# [NO MATCH] 006_04d74e12.jpg (Distance: 1.409)
# [NO MATCH] 006_30010640.jpg (Distance: 1.275)
# [NO MATCH] 006_46519378.jpg (Distance: 1.417)
# [MATCH] 006_8fc31fd7.jpg (Distance: 0.829)
# [NO MATCH] 006_96ea405c.jpg (Distance: 1.442)
# [NO MATCH] 006_a28f75e7.jpg (Distance: 1.391)
# [NO MATCH] 006_bbb6978e.jpg (Distance: 1.479)
# [NO MATCH] 006_eda1948f.jpg (Distance: 1.344)
# [NO MATCH] 007_0a40d399.jpg (Distance: 1.363)
# [MATCH] 007_1bc0bcd6.jpg (Distance: 0.734)
# [NO MATCH] 007_572cf58c.jpg (Distance: 1.373)
# [NO MATCH] 007_5b97655c.jpg (Distance: 1.415)
# [NO MATCH] 007_6ca7c622.jpg (Distance: 1.300)
# [NO MATCH] 007_76dc423a.jpg (Distance: 1.444)
# [NO MATCH] 007_9656ae64.jpg (Distance: 1.484)
# [NO MATCH] 007_ba0aa044.jpg (Distance: 1.421)
# [MATCH] 008_35d1be70.jpg (Distance: 0.695)
# [NO MATCH] 008_35daa4bc.jpg (Distance: 1.319)
# [NO MATCH] 008_3bfedab8.jpg (Distance: 1.427)
# [NO MATCH] 008_4d5e67ae.jpg (Distance: 1.393)
# [NO MATCH] 008_6c01eb52.jpg (Distance: 1.359)
# [!] No face found in ../../datasets/images/face/gallery\008_74cd0628.jpg
# [!] No face found in ../../datasets/images/face/gallery\008_cdaf39e7.jpg
# [NO MATCH] 008_f9ffe0c5.jpg (Distance: 1.417)
# [NO MATCH] 009_07c15c37.jpg (Distance: 1.368)
# [NO MATCH] 009_1f22d945.jpg (Distance: 1.408)
# [NO MATCH] 009_41aa3ed9.jpg (Distance: 1.365)
# [NO MATCH] 009_474a6b2e.jpg (Distance: 1.364)
# [NO MATCH] 009_8844bacc.jpg (Distance: 1.383)
# [NO MATCH] 009_a023db5b.jpg (Distance: 1.481)
# [NO MATCH] 009_b86449f6.jpg (Distance: 1.316)
# [MATCH] 009_f4a38fec.jpg (Distance: 0.705)
# [NO MATCH] 010_09f6d2fe.jpg (Distance: 1.412)
# [NO MATCH] 010_18d7b27c.jpg (Distance: 1.381)
# [NO MATCH] 010_2181b5f4.jpg (Distance: 1.394)
# [NO MATCH] 010_6102c83d.jpg (Distance: 1.376)
# [MATCH] 010_610eea60.jpg (Distance: 0.847)
# [NO MATCH] 010_8bd7dba1.jpg (Distance: 1.470)
# [NO MATCH] 010_ce5bd8a2.jpg (Distance: 1.384)
# [MATCH] 011_c826a613.jpg (Distance: 0.643)
# [MATCH] 012_563f0843.jpg (Distance: 0.638)
# [!] No face found in ../../datasets/images/face/gallery\013_f44c68a1.jpg
# [MATCH] 014_68248214.jpg (Distance: 0.808)
# [MATCH] 015_0474556e.jpg (Distance: 0.728)
# [MATCH] 016_8b4d3698.jpg (Distance: 0.680)
# [MATCH] 017_aadefe7b.jpg (Distance: 0.768)
# [MATCH] 018_14e5366f.jpg (Distance: 0.926)
# [MATCH] 019_3eb26944.jpg (Distance: 0.791)
# [MATCH] 020_6b7d8470.jpg (Distance: 0.672)
# [MATCH] 021_9ab18f1b.jpg (Distance: 0.747)
# [MATCH] 022_a0763313.jpg (Distance: 0.782)
# [MATCH] 023_4e454f96.jpg (Distance: 0.623)
# [MATCH] 024_bfac5f5b.jpg (Distance: 0.827)
# [MATCH] 025_4f2ec7c1.jpg (Distance: 0.807)
# [MATCH] 026_20c41942.jpg (Distance: 0.616)
# [MATCH] 027_2eab41f9.jpg (Distance: 0.546)
# [MATCH] 028_ce59b46d.jpg (Distance: 0.665)
# [MATCH] 029_30aec656.jpg (Distance: 0.689)
# [MATCH] 030_ddacf348.jpg (Distance: 0.559)
# [MATCH] 031_86ed9fca.jpg (Distance: 0.586)
# [MATCH] 032_4b3ee537.jpg (Distance: 0.589)
# [MATCH] 033_ef398d45.jpg (Distance: 0.821)
# [MATCH] 034_52d180f0.jpg (Distance: 0.683)
# [MATCH] 035_2a1b8bcf.jpg (Distance: 0.663)
# [NO MATCH] 036_c93144a5.jpg (Distance: 1.002)
# [MATCH] 037_f2fb045b.jpg (Distance: 0.737)
# [MATCH] 038_081386a5.jpg (Distance: 0.689)
# [MATCH] 039_13af66c8.jpg (Distance: 0.679)
# [MATCH] 040_2e8934ea.jpg (Distance: 0.586)
# [MATCH] 041_6ec992c9.jpg (Distance: 0.773)
# [MATCH] 042_05ce6c69.jpg (Distance: 0.911)
# [MATCH] 043_77e393de.jpg (Distance: 0.997)
# [MATCH] 044_18b89b8d.jpg (Distance: 0.729)
# [MATCH] 045_865604b0.jpg (Distance: 0.858)
# [MATCH] 046_31d6a7d8.jpg (Distance: 0.800)
# [MATCH] 047_6c6a66d2.jpg (Distance: 0.853)
# [MATCH] 048_8af82c54.jpg (Distance: 0.740)
# [MATCH] 049_9254f6f2.jpg (Distance: 0.673)
# [MATCH] 050_6641bd32.jpg (Distance: 0.792)
# [NO MATCH] 100_ec9fe97f.jpg (Distance: 1.290)
# [NO MATCH] 196_08de561a.jpg (Distance: 1.375)
# [NO MATCH] 197_ed22acef.jpg (Distance: 1.427)
# [NO MATCH] 198_e056989e.jpg (Distance: 1.467)
# [NO MATCH] 199_67b0ebbd.jpg (Distance: 1.421)
# [NO MATCH] 200_d8491f8c.jpg (Distance: 1.409)
#
# === Matches Found ===
# Image: 001_2288a4f6.jpg, Distance: 0.749
# Image: 002_331d0423.jpg, Distance: 0.690
# Image: 003_64926b97.jpg, Distance: 0.780
# Image: 004_18e08ab4.jpg, Distance: 0.740
# Image: 005_9406f32d.jpg, Distance: 0.539
# Image: 006_8fc31fd7.jpg, Distance: 0.829
# Image: 007_1bc0bcd6.jpg, Distance: 0.734
# Image: 008_35d1be70.jpg, Distance: 0.695
# Image: 009_f4a38fec.jpg, Distance: 0.705
# Image: 010_610eea60.jpg, Distance: 0.847
# Image: 011_c826a613.jpg, Distance: 0.643
# Image: 012_563f0843.jpg, Distance: 0.638
# Image: 014_68248214.jpg, Distance: 0.808
# Image: 015_0474556e.jpg, Distance: 0.728
# Image: 016_8b4d3698.jpg, Distance: 0.680
# Image: 017_aadefe7b.jpg, Distance: 0.768
# Image: 018_14e5366f.jpg, Distance: 0.926
# Image: 019_3eb26944.jpg, Distance: 0.791
# Image: 020_6b7d8470.jpg, Distance: 0.672
# Image: 021_9ab18f1b.jpg, Distance: 0.747
# Image: 022_a0763313.jpg, Distance: 0.782
# Image: 023_4e454f96.jpg, Distance: 0.623
# Image: 024_bfac5f5b.jpg, Distance: 0.827
# Image: 025_4f2ec7c1.jpg, Distance: 0.807
# Image: 026_20c41942.jpg, Distance: 0.616
# Image: 027_2eab41f9.jpg, Distance: 0.546
# Image: 028_ce59b46d.jpg, Distance: 0.665
# Image: 029_30aec656.jpg, Distance: 0.689
# Image: 030_ddacf348.jpg, Distance: 0.559
# Image: 031_86ed9fca.jpg, Distance: 0.586
# Image: 032_4b3ee537.jpg, Distance: 0.589
# Image: 033_ef398d45.jpg, Distance: 0.821
# Image: 034_52d180f0.jpg, Distance: 0.683
# Image: 035_2a1b8bcf.jpg, Distance: 0.663
# Image: 037_f2fb045b.jpg, Distance: 0.737
# Image: 038_081386a5.jpg, Distance: 0.689
# Image: 039_13af66c8.jpg, Distance: 0.679
# Image: 040_2e8934ea.jpg, Distance: 0.586
# Image: 041_6ec992c9.jpg, Distance: 0.773
# Image: 042_05ce6c69.jpg, Distance: 0.911
# Image: 043_77e393de.jpg, Distance: 0.997
# Image: 044_18b89b8d.jpg, Distance: 0.729
# Image: 045_865604b0.jpg, Distance: 0.858
# Image: 046_31d6a7d8.jpg, Distance: 0.800
# Image: 047_6c6a66d2.jpg, Distance: 0.853
# Image: 048_8af82c54.jpg, Distance: 0.740
# Image: 049_9254f6f2.jpg, Distance: 0.673
# Image: 050_6641bd32.jpg, Distance: 0.792
# ✅ Copied 001_2288a4f6.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 002_331d0423.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 003_64926b97.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 004_18e08ab4.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 005_9406f32d.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 006_8fc31fd7.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 007_1bc0bcd6.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 008_35d1be70.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 009_f4a38fec.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 010_610eea60.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 011_c826a613.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 012_563f0843.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 014_68248214.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 015_0474556e.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 016_8b4d3698.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 017_aadefe7b.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 018_14e5366f.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 019_3eb26944.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 020_6b7d8470.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 021_9ab18f1b.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 022_a0763313.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 023_4e454f96.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 024_bfac5f5b.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 025_4f2ec7c1.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 026_20c41942.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 027_2eab41f9.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 028_ce59b46d.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 029_30aec656.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 030_ddacf348.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 031_86ed9fca.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 032_4b3ee537.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 033_ef398d45.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 034_52d180f0.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 035_2a1b8bcf.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 037_f2fb045b.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 038_081386a5.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 039_13af66c8.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 040_2e8934ea.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 041_6ec992c9.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 042_05ce6c69.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 043_77e393de.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 044_18b89b8d.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 045_865604b0.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 046_31d6a7d8.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 047_6c6a66d2.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 048_8af82c54.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 049_9254f6f2.jpg to ../../datasets/images/face/matched_images\threshold_1.0
# ✅ Copied 050_6641bd32.jpg to ../../datasets/images/face/matched_images\threshold_1.0
#
# === Processing Threshold: 1.2 ===
# [NO MATCH] 001_08194468.jpg (Distance: 1.299)
# [NO MATCH] 001_08212dcd.jpg (Distance: 1.435)
# [MATCH] 001_2288a4f6.jpg (Distance: 0.749)
# [NO MATCH] 001_504d320d.jpg (Distance: 1.399)
# [NO MATCH] 001_5992faf7.jpg (Distance: 1.408)
# [NO MATCH] 001_5ef3e95c.jpg (Distance: 1.412)
# [NO MATCH] 001_986d6c22.jpg (Distance: 1.369)
# [!] No face found in ../../datasets/images/face/gallery\001_beebcee2.jpg
# [NO MATCH] 001_cb004eea.jpg (Distance: 1.417)
# [NO MATCH] 002_078f6fe5.jpg (Distance: 1.475)
# [NO MATCH] 002_24fab375.jpg (Distance: 1.443)
# [MATCH] 002_331d0423.jpg (Distance: 0.690)
# [NO MATCH] 002_36285f46.jpg (Distance: 1.396)
# [NO MATCH] 002_590bb980.jpg (Distance: 1.340)
# [NO MATCH] 002_6749a2c4.jpg (Distance: 1.428)
# [NO MATCH] 002_86e8aa58.jpg (Distance: 1.272)
# [NO MATCH] 002_ea6e259d.jpg (Distance: 1.398)
# [NO MATCH] 002_f6b26479.jpg (Distance: 1.397)
# [NO MATCH] 003_0e3303fc.jpg (Distance: 1.426)
# [NO MATCH] 003_21d0aae6.jpg (Distance: 1.367)
# [MATCH] 003_64926b97.jpg (Distance: 0.780)
# [NO MATCH] 003_85990366.jpg (Distance: 1.297)
# [NO MATCH] 003_936c5a43.jpg (Distance: 1.518)
# [NO MATCH] 003_98a0852a.jpg (Distance: 1.400)
# [NO MATCH] 003_acb20793.jpg (Distance: 1.352)
# [NO MATCH] 003_b416eed5.jpg (Distance: 1.409)
# [NO MATCH] 003_ed3fb7b1.jpg (Distance: 1.432)
# [NO MATCH] 004_0816d969.jpg (Distance: 1.333)
# [MATCH] 004_18e08ab4.jpg (Distance: 0.740)
# [NO MATCH] 004_3491d187.jpg (Distance: 1.387)
# [NO MATCH] 004_78847874.jpg (Distance: 1.459)
# [NO MATCH] 004_a5881d85.jpg (Distance: 1.366)
# [NO MATCH] 004_af012af1.jpg (Distance: 1.283)
# [NO MATCH] 004_af9b4c7c.jpg (Distance: 1.480)
# [NO MATCH] 004_bb16ac65.jpg (Distance: 1.444)
# [NO MATCH] 004_dc64d954.jpg (Distance: 1.365)
# [NO MATCH] 005_0623ac96.jpg (Distance: 1.374)
# [NO MATCH] 005_1fc7405f.jpg (Distance: 1.444)
# [NO MATCH] 005_2464c583.jpg (Distance: 1.406)
# [NO MATCH] 005_37066c18.jpg (Distance: 1.497)
# [NO MATCH] 005_7fe5b764.jpg (Distance: 1.298)
# [NO MATCH] 005_93b2fce9.jpg (Distance: 1.312)
# [MATCH] 005_9406f32d.jpg (Distance: 0.539)
# [NO MATCH] 005_b0b4e2fa.jpg (Distance: 1.435)
# [NO MATCH] 005_dac94cfe.jpg (Distance: 1.374)
# [NO MATCH] 006_04d74e12.jpg (Distance: 1.409)
# [NO MATCH] 006_30010640.jpg (Distance: 1.275)
# [NO MATCH] 006_46519378.jpg (Distance: 1.417)
# [MATCH] 006_8fc31fd7.jpg (Distance: 0.829)
# [NO MATCH] 006_96ea405c.jpg (Distance: 1.442)
# [NO MATCH] 006_a28f75e7.jpg (Distance: 1.391)
# [NO MATCH] 006_bbb6978e.jpg (Distance: 1.479)
# [NO MATCH] 006_eda1948f.jpg (Distance: 1.344)
# [NO MATCH] 007_0a40d399.jpg (Distance: 1.363)
# [MATCH] 007_1bc0bcd6.jpg (Distance: 0.734)
# [NO MATCH] 007_572cf58c.jpg (Distance: 1.373)
# [NO MATCH] 007_5b97655c.jpg (Distance: 1.415)
# [NO MATCH] 007_6ca7c622.jpg (Distance: 1.300)
# [NO MATCH] 007_76dc423a.jpg (Distance: 1.444)
# [NO MATCH] 007_9656ae64.jpg (Distance: 1.484)
# [NO MATCH] 007_ba0aa044.jpg (Distance: 1.421)
# [MATCH] 008_35d1be70.jpg (Distance: 0.695)
# [NO MATCH] 008_35daa4bc.jpg (Distance: 1.319)
# [NO MATCH] 008_3bfedab8.jpg (Distance: 1.427)
# [NO MATCH] 008_4d5e67ae.jpg (Distance: 1.393)
# [NO MATCH] 008_6c01eb52.jpg (Distance: 1.359)
# [!] No face found in ../../datasets/images/face/gallery\008_74cd0628.jpg
# [!] No face found in ../../datasets/images/face/gallery\008_cdaf39e7.jpg
# [NO MATCH] 008_f9ffe0c5.jpg (Distance: 1.417)
# [NO MATCH] 009_07c15c37.jpg (Distance: 1.368)
# [NO MATCH] 009_1f22d945.jpg (Distance: 1.408)
# [NO MATCH] 009_41aa3ed9.jpg (Distance: 1.365)
# [NO MATCH] 009_474a6b2e.jpg (Distance: 1.364)
# [NO MATCH] 009_8844bacc.jpg (Distance: 1.383)
# [NO MATCH] 009_a023db5b.jpg (Distance: 1.481)
# [NO MATCH] 009_b86449f6.jpg (Distance: 1.316)
# [MATCH] 009_f4a38fec.jpg (Distance: 0.705)
# [NO MATCH] 010_09f6d2fe.jpg (Distance: 1.412)
# [NO MATCH] 010_18d7b27c.jpg (Distance: 1.381)
# [NO MATCH] 010_2181b5f4.jpg (Distance: 1.394)
# [NO MATCH] 010_6102c83d.jpg (Distance: 1.376)
# [MATCH] 010_610eea60.jpg (Distance: 0.847)
# [NO MATCH] 010_8bd7dba1.jpg (Distance: 1.470)
# [NO MATCH] 010_ce5bd8a2.jpg (Distance: 1.384)
# [MATCH] 011_c826a613.jpg (Distance: 0.643)
# [MATCH] 012_563f0843.jpg (Distance: 0.638)
# [!] No face found in ../../datasets/images/face/gallery\013_f44c68a1.jpg
# [MATCH] 014_68248214.jpg (Distance: 0.808)
# [MATCH] 015_0474556e.jpg (Distance: 0.728)
# [MATCH] 016_8b4d3698.jpg (Distance: 0.680)
# [MATCH] 017_aadefe7b.jpg (Distance: 0.768)
# [MATCH] 018_14e5366f.jpg (Distance: 0.926)
# [MATCH] 019_3eb26944.jpg (Distance: 0.791)
# [MATCH] 020_6b7d8470.jpg (Distance: 0.672)
# [MATCH] 021_9ab18f1b.jpg (Distance: 0.747)
# [MATCH] 022_a0763313.jpg (Distance: 0.782)
# [MATCH] 023_4e454f96.jpg (Distance: 0.623)
# [MATCH] 024_bfac5f5b.jpg (Distance: 0.827)
# [MATCH] 025_4f2ec7c1.jpg (Distance: 0.807)
# [MATCH] 026_20c41942.jpg (Distance: 0.616)
# [MATCH] 027_2eab41f9.jpg (Distance: 0.546)
# [MATCH] 028_ce59b46d.jpg (Distance: 0.665)
# [MATCH] 029_30aec656.jpg (Distance: 0.689)
# [MATCH] 030_ddacf348.jpg (Distance: 0.559)
# [MATCH] 031_86ed9fca.jpg (Distance: 0.586)
# [MATCH] 032_4b3ee537.jpg (Distance: 0.589)
# [MATCH] 033_ef398d45.jpg (Distance: 0.821)
# [MATCH] 034_52d180f0.jpg (Distance: 0.683)
# [MATCH] 035_2a1b8bcf.jpg (Distance: 0.663)
# [MATCH] 036_c93144a5.jpg (Distance: 1.002)
# [MATCH] 037_f2fb045b.jpg (Distance: 0.737)
# [MATCH] 038_081386a5.jpg (Distance: 0.689)
# [MATCH] 039_13af66c8.jpg (Distance: 0.679)
# [MATCH] 040_2e8934ea.jpg (Distance: 0.586)
# [MATCH] 041_6ec992c9.jpg (Distance: 0.773)
# [MATCH] 042_05ce6c69.jpg (Distance: 0.911)
# [MATCH] 043_77e393de.jpg (Distance: 0.997)
# [MATCH] 044_18b89b8d.jpg (Distance: 0.729)
# [MATCH] 045_865604b0.jpg (Distance: 0.858)
# [MATCH] 046_31d6a7d8.jpg (Distance: 0.800)
# [MATCH] 047_6c6a66d2.jpg (Distance: 0.853)
# [MATCH] 048_8af82c54.jpg (Distance: 0.740)
# [MATCH] 049_9254f6f2.jpg (Distance: 0.673)
# [MATCH] 050_6641bd32.jpg (Distance: 0.792)
# [NO MATCH] 100_ec9fe97f.jpg (Distance: 1.290)
# [NO MATCH] 196_08de561a.jpg (Distance: 1.375)
# [NO MATCH] 197_ed22acef.jpg (Distance: 1.427)
# [NO MATCH] 198_e056989e.jpg (Distance: 1.467)
# [NO MATCH] 199_67b0ebbd.jpg (Distance: 1.421)
# [NO MATCH] 200_d8491f8c.jpg (Distance: 1.409)
#
# === Matches Found ===
# Image: 001_2288a4f6.jpg, Distance: 0.749
# Image: 002_331d0423.jpg, Distance: 0.690
# Image: 003_64926b97.jpg, Distance: 0.780
# Image: 004_18e08ab4.jpg, Distance: 0.740
# Image: 005_9406f32d.jpg, Distance: 0.539
# Image: 006_8fc31fd7.jpg, Distance: 0.829
# Image: 007_1bc0bcd6.jpg, Distance: 0.734
# Image: 008_35d1be70.jpg, Distance: 0.695
# Image: 009_f4a38fec.jpg, Distance: 0.705
# Image: 010_610eea60.jpg, Distance: 0.847
# Image: 011_c826a613.jpg, Distance: 0.643
# Image: 012_563f0843.jpg, Distance: 0.638
# Image: 014_68248214.jpg, Distance: 0.808
# Image: 015_0474556e.jpg, Distance: 0.728
# Image: 016_8b4d3698.jpg, Distance: 0.680
# Image: 017_aadefe7b.jpg, Distance: 0.768
# Image: 018_14e5366f.jpg, Distance: 0.926
# Image: 019_3eb26944.jpg, Distance: 0.791
# Image: 020_6b7d8470.jpg, Distance: 0.672
# Image: 021_9ab18f1b.jpg, Distance: 0.747
# Image: 022_a0763313.jpg, Distance: 0.782
# Image: 023_4e454f96.jpg, Distance: 0.623
# Image: 024_bfac5f5b.jpg, Distance: 0.827
# Image: 025_4f2ec7c1.jpg, Distance: 0.807
# Image: 026_20c41942.jpg, Distance: 0.616
# Image: 027_2eab41f9.jpg, Distance: 0.546
# Image: 028_ce59b46d.jpg, Distance: 0.665
# Image: 029_30aec656.jpg, Distance: 0.689
# Image: 030_ddacf348.jpg, Distance: 0.559
# Image: 031_86ed9fca.jpg, Distance: 0.586
# Image: 032_4b3ee537.jpg, Distance: 0.589
# Image: 033_ef398d45.jpg, Distance: 0.821
# Image: 034_52d180f0.jpg, Distance: 0.683
# Image: 035_2a1b8bcf.jpg, Distance: 0.663
# Image: 036_c93144a5.jpg, Distance: 1.002
# Image: 037_f2fb045b.jpg, Distance: 0.737
# Image: 038_081386a5.jpg, Distance: 0.689
# Image: 039_13af66c8.jpg, Distance: 0.679
# Image: 040_2e8934ea.jpg, Distance: 0.586
# Image: 041_6ec992c9.jpg, Distance: 0.773
# Image: 042_05ce6c69.jpg, Distance: 0.911
# Image: 043_77e393de.jpg, Distance: 0.997
# Image: 044_18b89b8d.jpg, Distance: 0.729
# Image: 045_865604b0.jpg, Distance: 0.858
# Image: 046_31d6a7d8.jpg, Distance: 0.800
# Image: 047_6c6a66d2.jpg, Distance: 0.853
# Image: 048_8af82c54.jpg, Distance: 0.740
# Image: 049_9254f6f2.jpg, Distance: 0.673
# Image: 050_6641bd32.jpg, Distance: 0.792
# ✅ Copied 001_2288a4f6.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 002_331d0423.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 003_64926b97.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 004_18e08ab4.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 005_9406f32d.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 006_8fc31fd7.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 007_1bc0bcd6.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 008_35d1be70.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 009_f4a38fec.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 010_610eea60.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 011_c826a613.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 012_563f0843.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 014_68248214.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 015_0474556e.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 016_8b4d3698.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 017_aadefe7b.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 018_14e5366f.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 019_3eb26944.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 020_6b7d8470.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 021_9ab18f1b.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 022_a0763313.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 023_4e454f96.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 024_bfac5f5b.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 025_4f2ec7c1.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 026_20c41942.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 027_2eab41f9.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 028_ce59b46d.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 029_30aec656.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 030_ddacf348.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 031_86ed9fca.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 032_4b3ee537.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 033_ef398d45.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 034_52d180f0.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 035_2a1b8bcf.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 036_c93144a5.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 037_f2fb045b.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 038_081386a5.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 039_13af66c8.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 040_2e8934ea.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 041_6ec992c9.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 042_05ce6c69.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 043_77e393de.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 044_18b89b8d.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 045_865604b0.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 046_31d6a7d8.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 047_6c6a66d2.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 048_8af82c54.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 049_9254f6f2.jpg to ../../datasets/images/face/matched_images\threshold_1.2
# ✅ Copied 050_6641bd32.jpg to ../../datasets/images/face/matched_images\threshold_1.2
#
# === FINAL REPORT ===
# Thresholds used: [0.5, 0.7, 1.0, 1.2]
# Total suspect images: 6
# Total dataset images processed: 126
# Time used: 359.15 seconds
# ======================
