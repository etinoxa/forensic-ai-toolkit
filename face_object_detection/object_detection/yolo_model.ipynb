# %%
# !pip install ultralytics
# !pip install ultralytics pillow opencv-python
# Out:
# Requirement already satisfied: ultralytics in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (8.3.142)
# Requirement already satisfied: numpy>=1.23.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (0.22.0)
# Requirement already satisfied: tqdm>=4.64.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: colorama in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\etinoxa\interpreters\python\projects\ai_forensics\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import os
from PIL import Image
import numpy as np
import cv2
from ultralytics import YOLO

# %%
# === Load Pretrained YOLOv8 Model ===
yolo_model = YOLO('yolov8n.pt')  # You can switch to yolov8s.pt, yolov8m.pt, etc.

# %%
# === Load Any Image Format ===
def load_image_any_format(img_path):
    img_pil = Image.open(img_path)
    if img_pil.format == 'GIF':
        img_pil.seek(0)
    img_pil = img_pil.convert('RGB')
    img_np = np.array(img_pil)
    return cv2.cvtColor(img_np, cv2.COLOR_RGB2BGR)

# %%
def detect_objects(img_path, expected_objects=None, save_annotated=False, output_dir="./detections"):
    image = load_image_any_format(img_path)
    results = yolo_model(image)

    detected_objects = []
    match_found = False

    for result in results:
        for box in result.boxes:
            cls_id = int(box.cls[0])
            conf = float(box.conf[0])
            label = yolo_model.names[cls_id]
            detected_objects.append((label, conf))

            if expected_objects is None or label.lower() in expected_objects:
                match_found = True
                print(f"[MATCHED] {label} ({conf:.2f})")

    if save_annotated and match_found:
        os.makedirs(output_dir, exist_ok=True)
        save_path = os.path.join(output_dir, os.path.basename(img_path))
        results[0].save(filename=save_path)
        print(f"✅ Saved annotated image to {save_path}")

    return detected_objects if match_found else []

# %%
# === Batch Detection With Filtering ===
def detect_in_folder(folder_path, output_folder="./detections", expected_objects=None, save_annotated=True):
    supported_exts = (".jpg", ".jpeg", ".png", ".bmp", ".tiff", ".gif")
    expected_objects = [obj.lower() for obj in expected_objects] if expected_objects else None

    for img_name in os.listdir(folder_path):
        if img_name.lower().endswith(supported_exts):
            img_path = os.path.join(folder_path, img_name)
            print(f"\n📂 Processing {img_name}")
            detected = detect_objects(img_path, expected_objects=expected_objects, save_annotated=save_annotated, output_dir=output_folder)
            if not detected:
                print("No expected objects found.")

# %%
# === Main Runner ===
image_folder = r"C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\raw"
output_folder = r"C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections"
expected_objects = ["knife", "gun"]  # You can modify this

detect_in_folder(image_folder, output_folder=output_folder, expected_objects=expected_objects, save_annotated=True)
# Out:
# 📂 Processing --------_------_jpg.rf.08c002808911e42dcb831337e2eed710.jpg
#
# 0: 640x640 1 vase, 186.9ms
# Speed: 5.9ms preprocess, 186.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.0c6fff42bd233e5fb0e2ef448b4e4db1.jpg
#
# 0: 640x640 (no detections), 116.1ms
# Speed: 5.6ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.148da60814a734f1e592d3e89b784c47.jpg
#
# 0: 640x640 (no detections), 116.7ms
# Speed: 4.2ms preprocess, 116.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.2b5bd69b5834c97c3cf5951759c2b640.jpg
#
# 0: 640x640 (no detections), 120.2ms
# Speed: 4.0ms preprocess, 120.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.2f14618aacad49b58b36d109b02f4cd0.jpg
#
# 0: 640x640 2 knifes, 1 remote, 1 keyboard, 3 scissorss, 120.3ms
# Speed: 4.2ms preprocess, 120.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.41)
# [MATCHED] knife (0.39)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.2f14618aacad49b58b36d109b02f4cd0.jpg
#
# 📂 Processing --------_------_jpg.rf.3f2aa7d7d878197c0da970dc314619d8.jpg
#
# 0: 640x640 (no detections), 116.1ms
# Speed: 4.2ms preprocess, 116.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.4eb0868f6cd41827c921043ddfa37ff9.jpg
#
# 0: 640x640 4 knifes, 1 scissors, 115.9ms
# Speed: 4.4ms preprocess, 115.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.67)
# [MATCHED] knife (0.59)
# [MATCHED] knife (0.54)
# [MATCHED] knife (0.34)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.4eb0868f6cd41827c921043ddfa37ff9.jpg
#
# 📂 Processing --------_------_jpg.rf.5b5353191623109010164c7a35da4c4b.jpg
#
# 0: 640x640 (no detections), 134.3ms
# Speed: 4.7ms preprocess, 134.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.660a10b09f7c2092613cef14ef74d00d.jpg
#
# 0: 640x640 (no detections), 142.3ms
# Speed: 4.5ms preprocess, 142.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.73a95f4c2fe5cfa9c071b8f4d2a02139.jpg
#
# 0: 640x640 (no detections), 139.2ms
# Speed: 4.3ms preprocess, 139.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.74499d40896f9307ee0188dff30a3977.jpg
#
# 0: 640x640 1 knife, 1 scissors, 159.6ms
# Speed: 4.8ms preprocess, 159.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.26)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.74499d40896f9307ee0188dff30a3977.jpg
#
# 📂 Processing --------_------_jpg.rf.74ffcb78991d029732f8df90f11d4542.jpg
#
# 0: 640x640 (no detections), 122.8ms
# Speed: 4.2ms preprocess, 122.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.7a13bea7b6f60763befa493df27e5dde.jpg
#
# 0: 640x640 4 knifes, 1 keyboard, 1 scissors, 118.3ms
# Speed: 4.4ms preprocess, 118.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.63)
# [MATCHED] knife (0.49)
# [MATCHED] knife (0.31)
# [MATCHED] knife (0.31)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.7a13bea7b6f60763befa493df27e5dde.jpg
#
# 📂 Processing --------_------_jpg.rf.87cd0152d0e0f51c2977b3b35a216f6d.jpg
#
# 0: 640x640 1 knife, 127.9ms
# Speed: 4.6ms preprocess, 127.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.36)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.87cd0152d0e0f51c2977b3b35a216f6d.jpg
#
# 📂 Processing --------_------_jpg.rf.9204bbdc2f81d68cf106fdb070c5dc36.jpg
#
# 0: 640x640 3 knifes, 2 scissorss, 1 toothbrush, 129.6ms
# Speed: 5.3ms preprocess, 129.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.63)
# [MATCHED] knife (0.61)
# [MATCHED] knife (0.28)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.9204bbdc2f81d68cf106fdb070c5dc36.jpg
#
# 📂 Processing --------_------_jpg.rf.9b4ce92de98f3d1f7cac17a560ddbdfe.jpg
#
# 0: 640x640 (no detections), 147.7ms
# Speed: 5.4ms preprocess, 147.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.a07a927ebc755279a6d430f47f786c3a.jpg
#
# 0: 640x640 1 person, 131.7ms
# Speed: 4.5ms preprocess, 131.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.a34ba4c1ed5c93d2f9bb8289a50a4e46.jpg
#
# 0: 640x640 (no detections), 149.9ms
# Speed: 5.8ms preprocess, 149.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.d538ddbbe1d74793f38f032d7cd5ee51.jpg
#
# 0: 640x640 4 knifes, 140.5ms
# Speed: 4.5ms preprocess, 140.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.61)
# [MATCHED] knife (0.57)
# [MATCHED] knife (0.57)
# [MATCHED] knife (0.35)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.d538ddbbe1d74793f38f032d7cd5ee51.jpg
#
# 📂 Processing --------_------_jpg.rf.e0f3feb554a616bb4afd53b9f612ef2e.jpg
#
# 0: 640x640 1 potted plant, 175.8ms
# Speed: 4.3ms preprocess, 175.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.e8bb061d9b77883aa74f4e9b5ccb3db4.jpg
#
# 0: 640x640 2 knifes, 129.4ms
# Speed: 4.2ms preprocess, 129.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.82)
# [MATCHED] knife (0.72)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.e8bb061d9b77883aa74f4e9b5ccb3db4.jpg
#
# 📂 Processing --------_------_jpg.rf.ee7e92b6a731c6bd2c5687109ad58aad.jpg
#
# 0: 640x640 (no detections), 120.7ms
# Speed: 4.7ms preprocess, 120.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.ef2feb5f20c0d21a1a8751ae1e3b6eab.jpg
#
# 0: 640x640 1 person, 139.1ms
# Speed: 4.1ms preprocess, 139.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.f89f768fda731c4eebcba7937f2b42a2.jpg
#
# 0: 640x640 (no detections), 135.5ms
# Speed: 5.2ms preprocess, 135.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing --------_------_jpg.rf.fe44ae9cc8d1c4369c5761abf4d7e197.jpg
#
# 0: 640x640 1 knife, 1 scissors, 140.7ms
# Speed: 4.5ms preprocess, 140.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.26)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\--------_------_jpg.rf.fe44ae9cc8d1c4369c5761abf4d7e197.jpg
#
# 📂 Processing --------_------_jpg.rf.fedb4a194a6da4684351270b167c686c.jpg
#
# 0: 640x640 (no detections), 130.2ms
# Speed: 5.4ms preprocess, 130.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing 445_jpg.rf.2e04379013684f454abbc00564910fcc.jpg
#
# 0: 640x640 (no detections), 144.0ms
# Speed: 4.5ms preprocess, 144.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00154_jpg.rf.d56723a3de6d775966551d0d0e8add67.jpg
#
# 0: 640x640 1 person, 1 clock, 136.5ms
# Speed: 4.6ms preprocess, 136.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00160_jpg.rf.23c17f2cfeacd7873e38995e4832e0c1.jpg
#
# 0: 640x640 1 person, 1 clock, 174.7ms
# Speed: 5.5ms preprocess, 174.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00166_jpg.rf.d0f4052c7acfd9a298f657d3c56279e3.jpg
#
# 0: 640x640 1 person, 1 clock, 131.6ms
# Speed: 4.9ms preprocess, 131.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00169_jpg.rf.0a602b61133774dd78c98b0031ac834a.jpg
#
# 0: 640x640 1 person, 117.0ms
# Speed: 4.3ms preprocess, 117.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00190_jpg.rf.2ced39a08320a9db30ec44375062a1b8.jpg
#
# 0: 640x640 1 person, 1 clock, 137.5ms
# Speed: 4.4ms preprocess, 137.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00235_jpg.rf.cdc8544dcec688136230ff2a24b14950.jpg
#
# 0: 640x640 1 person, 1 clock, 128.6ms
# Speed: 4.2ms preprocess, 128.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00265_jpg.rf.0488bc6053bb8bf3a55300c7caf4d269.jpg
#
# 0: 640x640 1 person, 1 clock, 144.4ms
# Speed: 4.3ms preprocess, 144.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00271_jpg.rf.4ea36beb75644e4e876b60176934f9b2.jpg
#
# 0: 640x640 1 person, 142.7ms
# Speed: 4.4ms preprocess, 142.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00274_jpg.rf.76e7b5de2b7a3d2cc14e374d935ebc99.jpg
#
# 0: 640x640 1 person, 140.3ms
# Speed: 4.5ms preprocess, 140.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00277_jpg.rf.1b722bd1914427b42b9579722538945d.jpg
#
# 0: 640x640 1 person, 1 remote, 1 clock, 140.7ms
# Speed: 5.3ms preprocess, 140.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00280_jpg.rf.59ffd703fab71ff078f7efffb1b6d8b7.jpg
#
# 0: 640x640 1 person, 1 clock, 121.6ms
# Speed: 5.3ms preprocess, 121.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00283_jpg.rf.ec08f566106f2c1aff60a6ef0fa4b3ca.jpg
#
# 0: 640x640 1 person, 109.0ms
# Speed: 4.1ms preprocess, 109.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00286_jpg.rf.b0ff300d2647eefad04c3f85da899c55.jpg
#
# 0: 640x640 1 person, 1 clock, 105.8ms
# Speed: 4.3ms preprocess, 105.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00292_jpg.rf.46ef81c4bad3ec0bd519351bc429dc86.jpg
#
# 0: 640x640 1 person, 1 clock, 127.9ms
# Speed: 5.2ms preprocess, 127.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00295_jpg.rf.4d6f38ca50209db652317ac7898e9e12.jpg
#
# 0: 640x640 1 person, 126.4ms
# Speed: 5.2ms preprocess, 126.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00298_jpg.rf.90347ebc304e4d673c568b1ac19d53ce.jpg
#
# 0: 640x640 1 person, 1 clock, 126.4ms
# Speed: 5.0ms preprocess, 126.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00301_jpg.rf.c5edc5525d1ae57b6d94652da47341d5.jpg
#
# 0: 640x640 1 person, 141.4ms
# Speed: 4.8ms preprocess, 141.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00304_jpg.rf.8d7d47c68f2f8485978b4c4e453f0b87.jpg
#
# 0: 640x640 1 person, 131.5ms
# Speed: 6.1ms preprocess, 131.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00313_jpg.rf.bc647384bbc01e9d619f3f5f476e1b99.jpg
#
# 0: 640x640 1 person, 2 clocks, 119.5ms
# Speed: 4.9ms preprocess, 119.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00316_jpg.rf.86e3ad092aaf7bad1dea214f2fb8524b.jpg
#
# 0: 640x640 1 person, 1 clock, 115.8ms
# Speed: 4.5ms preprocess, 115.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00319_jpg.rf.75e92bfc8e81051765007adb8e8d708c.jpg
#
# 0: 640x640 1 person, 1 clock, 117.2ms
# Speed: 4.4ms preprocess, 117.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00328_jpg.rf.adbdd789345a93f30c1bf7edb87e98cc.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1 clock, 96.4ms
# Speed: 4.5ms preprocess, 96.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00346_jpg.rf.b1e1cd89fe61387de53353ff49002c35.jpg
#
# 0: 640x640 1 person, 1 clock, 111.9ms
# Speed: 4.3ms preprocess, 111.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00349_jpg.rf.911aaca88c359d582c6b9c0bc183cd74.jpg
#
# 0: 640x640 1 person, 1 clock, 119.4ms
# Speed: 5.2ms preprocess, 119.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00370_jpg.rf.d1b3040ed3bdee0eed3bba9faafcd1f1.jpg
#
# 0: 640x640 1 person, 110.6ms
# Speed: 4.2ms preprocess, 110.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00421_jpg.rf.b7ac40695cd7a034212f3a0556441f28.jpg
#
# 0: 640x640 1 person, 1 clock, 117.2ms
# Speed: 5.1ms preprocess, 117.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00430_jpg.rf.96d982419a6d9599251ac97550753706.jpg
#
# 0: 640x640 1 person, 1 clock, 114.7ms
# Speed: 5.3ms preprocess, 114.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABbframe00457_jpg.rf.13a55678a98891aae40e7f4006ff799f.jpg
#
# 0: 640x640 1 person, 1 tie, 113.5ms
# Speed: 4.6ms preprocess, 113.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00127_jpg.rf.f39cfc80859ccf4dcc3c62ebcaf8979c.jpg
#
# 0: 640x640 1 person, 1 clock, 115.8ms
# Speed: 4.5ms preprocess, 115.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00133_jpg.rf.676153028c27ccef56121d2b75b3ed63.jpg
#
# 0: 640x640 1 person, 1 clock, 104.7ms
# Speed: 4.4ms preprocess, 104.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00142_jpg.rf.176131dcbaecbe32c5dd55ccd05fd920.jpg
#
# 0: 640x640 1 person, 1 clock, 113.7ms
# Speed: 4.8ms preprocess, 113.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00157_jpg.rf.1024ee338c34975dc3ec9405ab9da2b3.jpg
#
# 0: 640x640 1 person, 1 clock, 121.4ms
# Speed: 4.3ms preprocess, 121.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00163_jpg.rf.b35eaad94e13cec3058200f89817c0f8.jpg
#
# 0: 640x640 1 person, 1 clock, 113.1ms
# Speed: 4.2ms preprocess, 113.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00172_jpg.rf.99dd984a71c916268089390669bca4dd.jpg
#
# 0: 640x640 1 person, 1 clock, 132.7ms
# Speed: 4.6ms preprocess, 132.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00211_jpg.rf.596352d23c2bd937e2a26c56ff084a04.jpg
#
# 0: 640x640 1 person, 1 cell phone, 119.5ms
# Speed: 4.1ms preprocess, 119.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00226_jpg.rf.e824fe8c2d23f8443bfe36490b8374b6.jpg
#
# 0: 640x640 1 person, 1 clock, 130.2ms
# Speed: 4.9ms preprocess, 130.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00271_jpg.rf.919066733ac88fa1ea6442730548bb24.jpg
#
# 0: 640x640 1 person, 161.1ms
# Speed: 6.4ms preprocess, 161.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00277_jpg.rf.c687fcf6cd0a0d34490716d22b6dd51a.jpg
#
# 0: 640x640 1 person, 122.6ms
# Speed: 4.2ms preprocess, 122.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00289_jpg.rf.6b5c700d51f5a0680a26562cc7e9e967.jpg
#
# 0: 640x640 1 person, 104.6ms
# Speed: 4.2ms preprocess, 104.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00301_jpg.rf.f009b0e538d00c922686bb8df2d069a8.jpg
#
# 0: 640x640 1 person, 111.6ms
# Speed: 4.9ms preprocess, 111.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00313_jpg.rf.92cc70f2b90904698cdaa18cd2b57477.jpg
#
# 0: 640x640 1 person, 108.0ms
# Speed: 4.3ms preprocess, 108.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00322_jpg.rf.4edc65002cbb165123c1c23b2b4e09f1.jpg
#
# 0: 640x640 1 person, 107.8ms
# Speed: 4.1ms preprocess, 107.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABmframe00412_jpg.rf.e3e666912cd88c3404e2f1962b6bcfea.jpg
#
# 0: 640x640 1 person, 1 clock, 100.9ms
# Speed: 4.3ms preprocess, 100.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00001_jpg.rf.36233bbeeeb5ff0e07ecc51b0fd014e3.jpg
#
# 0: 640x640 1 person, 1 clock, 107.5ms
# Speed: 4.2ms preprocess, 107.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00004_jpg.rf.f6b27a83e417eeadd9ac33b13cd2e210.jpg
#
# 0: 640x640 1 person, 110.8ms
# Speed: 4.2ms preprocess, 110.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00019_jpg.rf.452d8624f6d5a67b14393b30c1aa38a9.jpg
#
# 0: 640x640 1 person, 98.4ms
# Speed: 5.8ms preprocess, 98.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00064_jpg.rf.4b4694ef1f2a98df47aaafa30b968ceb.jpg
#
# 0: 640x640 1 person, 93.2ms
# Speed: 4.0ms preprocess, 93.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00067_jpg.rf.75749d0609ebd6a2f594373431cef989.jpg
#
# 0: 640x640 1 person, 1 clock, 100.0ms
# Speed: 4.5ms preprocess, 100.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00094_jpg.rf.36dc799bd6eebe562f1ba45de15b5c64.jpg
#
# 0: 640x640 1 person, 1 clock, 98.3ms
# Speed: 4.1ms preprocess, 98.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00100_jpg.rf.2085458c3860ad6532f35445a53528b1.jpg
#
# 0: 640x640 1 person, 1 tie, 100.2ms
# Speed: 4.9ms preprocess, 100.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00133_jpg.rf.d956777b775c8f8611785df232483bcb.jpg
#
# 0: 640x640 1 person, 108.3ms
# Speed: 5.0ms preprocess, 108.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00151_jpg.rf.34817e076edecd2185a5d978e303be51.jpg
#
# 0: 640x640 1 person, 1 clock, 111.8ms
# Speed: 4.2ms preprocess, 111.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00184_jpg.rf.4febb442f35d5d6bdae226a43d884890.jpg
#
# 0: 640x640 1 person, 1 clock, 104.1ms
# Speed: 4.8ms preprocess, 104.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00190_jpg.rf.56710cc8369d47891023209aa88abfc7.jpg
#
# 0: 640x640 1 person, 1 clock, 100.8ms
# Speed: 4.2ms preprocess, 100.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00214_jpg.rf.ae6c1e7d4c8e474123569e8bfa08f701.jpg
#
# 0: 640x640 1 person, 1 clock, 108.1ms
# Speed: 4.2ms preprocess, 108.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00223_jpg.rf.2e0d55585fa7f395666315e4f0881550.jpg
#
# 0: 640x640 1 person, 1 clock, 110.7ms
# Speed: 4.5ms preprocess, 110.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00241_jpg.rf.d35565984e7b8c28f31b3664b3e79710.jpg
#
# 0: 640x640 1 person, 2 clocks, 115.1ms
# Speed: 4.2ms preprocess, 115.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing ABsframe00256_jpg.rf.8812293daacb638e29c5ed7e96f26fee.jpg
#
# 0: 640x640 1 person, 1 clock, 124.3ms
# Speed: 4.2ms preprocess, 124.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1-_jpg.rf.18279624db90b5e46a11a034a54df7e5.jpg
#
# 0: 640x640 (no detections), 131.7ms
# Speed: 5.3ms preprocess, 131.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--10-_jpg.rf.f513a900e55937e97e2125e57131295e.jpg
#
# 0: 640x640 1 person, 113.9ms
# Speed: 5.1ms preprocess, 113.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--100-_jpg.rf.f94bf72b563b4ee03dbc049d6e3614ba.jpg
#
# 0: 640x640 2 persons, 115.3ms
# Speed: 4.1ms preprocess, 115.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1000-_jpg.rf.c1e88f70c300deecad23d14748667259.jpg
#
# 0: 640x640 3 persons, 124.9ms
# Speed: 4.9ms preprocess, 124.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1001-_jpg.rf.97cb5a9d5694392b1b208a911246c914.jpg
#
# 0: 640x640 1 person, 125.9ms
# Speed: 4.5ms preprocess, 125.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1002-_jpg.rf.b19fdd140f9689fc25594d33e9e0f2bc.jpg
#
# 0: 640x640 1 person, 1 cell phone, 111.4ms
# Speed: 4.3ms preprocess, 111.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1003-_jpg.rf.bfc024c1335a6668455751bea1fdcc69.jpg
#
# 0: 640x640 1 traffic light, 1 knife, 115.7ms
# Speed: 4.2ms preprocess, 115.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.28)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\armas--1003-_jpg.rf.bfc024c1335a6668455751bea1fdcc69.jpg
#
# 📂 Processing armas--1004-_jpg.rf.e5298bd651ae8e16b8cbfcf3ff2e3f34.jpg
#
# 0: 640x640 1 person, 120.2ms
# Speed: 5.2ms preprocess, 120.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1005-_jpg.rf.39a274f8d98b72223b3fc40b0a412665.jpg
#
# 0: 640x640 (no detections), 123.5ms
# Speed: 4.2ms preprocess, 123.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1007-_jpg.rf.fa815f49d6135e18730c38694d57f3de.jpg
#
# 0: 640x640 (no detections), 138.4ms
# Speed: 4.5ms preprocess, 138.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--101-_jpg.rf.77bc82e7280d98568c183fc496e92633.jpg
#
# 0: 640x640 1 person, 137.0ms
# Speed: 5.3ms preprocess, 137.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1010-_jpg.rf.ebf8977692c61756ebdeccde8394adcc.jpg
#
# 0: 640x640 1 person, 131.2ms
# Speed: 4.3ms preprocess, 131.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1011-_jpg.rf.fd5a7bb18c0e21c0bd684388b9206ddc.jpg
#
# 0: 640x640 2 persons, 132.9ms
# Speed: 4.3ms preprocess, 132.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1012-_jpg.rf.41b24cfab8c8363b85ed901a302c0f01.jpg
#
# 0: 640x640 1 person, 131.1ms
# Speed: 5.2ms preprocess, 131.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1013-_jpg.rf.0e5a7c8c271237337237a09504f2813d.jpg
#
# 0: 640x640 1 person, 1 bird, 126.8ms
# Speed: 6.2ms preprocess, 126.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1015-_jpg.rf.59ab5977e55dc4234633985ff62f07c6.jpg
#
# 0: 640x640 1 person, 2 horses, 2 clocks, 115.9ms
# Speed: 4.1ms preprocess, 115.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1018-_jpg.rf.687f8b9c8d0ae2eb34aa81db13852264.jpg
#
# 0: 640x640 3 persons, 136.8ms
# Speed: 5.3ms preprocess, 136.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1019-_jpg.rf.e319b5b4c3d256cd7f7d7d9ba0d88d10.jpg
#
# 0: 640x640 1 cat, 144.1ms
# Speed: 5.3ms preprocess, 144.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--102-_jpg.rf.4824ef8648953c9374eb287fce6520f3.jpg
#
# 0: 640x640 2 persons, 119.1ms
# Speed: 4.7ms preprocess, 119.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1021-_jpg.rf.9427bc4497bed2628c2fb81962ef9d5b.jpg
#
# 0: 640x640 (no detections), 125.1ms
# Speed: 4.4ms preprocess, 125.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1023-_jpg.rf.633ed2a97e609c942112abda3ad3a6f3.jpg
#
# 0: 640x640 (no detections), 142.8ms
# Speed: 4.4ms preprocess, 142.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1024-_jpg.rf.93293e029dcc1525fed10d2425f5952a.jpg
#
# 0: 640x640 1 person, 1 tennis racket, 154.6ms
# Speed: 6.3ms preprocess, 154.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1025-_jpg.rf.341735c58841877d3b1b2e84cda5e39c.jpg
#
# 0: 640x640 1 person, 140.7ms
# Speed: 5.2ms preprocess, 140.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1026-_jpg.rf.d57b9963116d4603b343d70748f5bdf4.jpg
#
# 0: 640x640 1 person, 132.1ms
# Speed: 5.6ms preprocess, 132.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1027-_jpg.rf.f4c42f8e62a76a8738f6b58405a6b5f5.jpg
#
# 0: 640x640 3 persons, 118.5ms
# Speed: 4.4ms preprocess, 118.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1028-_jpg.rf.c4c910deab4e00038be10fa3b20a2899.jpg
#
# 0: 640x640 2 persons, 1 book, 115.2ms
# Speed: 4.1ms preprocess, 115.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1029-_jpg.rf.89e99fad00ae8f37ccc11aa89914011d.jpg
#
# 0: 640x640 1 person, 135.0ms
# Speed: 4.7ms preprocess, 135.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--103-_jpg.rf.b3e26f16608442adf4c094ebd8f2e1b8.jpg
#
# 0: 640x640 1 person, 1 cell phone, 129.1ms
# Speed: 4.5ms preprocess, 129.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1032-_jpg.rf.0e0fbd9d86acd3f6f8426d8fe714dffc.jpg
#
# 0: 640x640 2 persons, 137.9ms
# Speed: 7.1ms preprocess, 137.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1033-_jpg.rf.914430c33778c05ff47e6dbbaa864f0a.jpg
#
# 0: 640x640 1 person, 123.6ms
# Speed: 4.3ms preprocess, 123.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1034-_jpg.rf.70fb372567aff07dc7886230bd089fd0.jpg
#
# 0: 640x640 (no detections), 131.1ms
# Speed: 4.4ms preprocess, 131.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1035-_jpg.rf.0c459a7eae8263269876db1fe7e25318.jpg
#
# 0: 640x640 1 person, 114.3ms
# Speed: 4.4ms preprocess, 114.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1036-_jpg.rf.d1cc60286c26d737ddf68e9e3ed78751.jpg
#
# 0: 640x640 1 person, 123.0ms
# Speed: 4.1ms preprocess, 123.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1037-_jpg.rf.d33f4f61b0bbea45e3fbe2aa0680514f.jpg
#
# 0: 640x640 1 person, 115.0ms
# Speed: 5.8ms preprocess, 115.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1038-_jpg.rf.35b8ef8a65828aec4fb75480fd5cf1cd.jpg
#
# 0: 640x640 (no detections), 112.4ms
# Speed: 4.2ms preprocess, 112.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1039-_jpg.rf.33476e810abee95485b16459dba3de68.jpg
#
# 0: 640x640 1 person, 1 cell phone, 136.9ms
# Speed: 4.4ms preprocess, 136.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--104-_jpg.rf.dff12de2a01337fea3183c0efb68b595.jpg
#
# 0: 640x640 2 persons, 132.8ms
# Speed: 7.1ms preprocess, 132.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1040-_jpg.rf.97b897a495046766da8c888bd55d0f02.jpg
#
# 0: 640x640 1 person, 143.4ms
# Speed: 4.4ms preprocess, 143.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1041-_jpg.rf.f26660bf41c43e6c24200c49c0943b9b.jpg
#
# 0: 640x640 1 person, 126.9ms
# Speed: 4.7ms preprocess, 126.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1044-_jpg.rf.6cbcb88aeb6d639928111e0f0f12be12.jpg
#
# 0: 640x640 1 person, 153.2ms
# Speed: 5.0ms preprocess, 153.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1046-_jpg.rf.00f7a36c0206d48badcc743d1228e107.jpg
#
# 0: 640x640 1 traffic light, 148.2ms
# Speed: 5.2ms preprocess, 148.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1048-_jpg.rf.ce2672b217c95276e87dedd8b37be8f1.jpg
#
# 0: 640x640 1 person, 131.8ms
# Speed: 4.8ms preprocess, 131.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1049-_jpg.rf.9c3469f17c2314ae48d7fd3ae777494a.jpg
#
# 0: 640x640 1 person, 1 cell phone, 104.3ms
# Speed: 4.3ms preprocess, 104.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1050-_jpg.rf.e9051559a6668cfc1d61e16e9658625c.jpg
#
# 0: 640x640 1 suitcase, 107.5ms
# Speed: 4.0ms preprocess, 107.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1051-_jpg.rf.c6e022e34d5000a85ef2bdb8d399f819.jpg
#
# 0: 640x640 1 person, 126.3ms
# Speed: 4.1ms preprocess, 126.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1052-_jpg.rf.5630e22f4d540e8467db02727922b484.jpg
#
# 0: 640x640 (no detections), 138.7ms
# Speed: 4.6ms preprocess, 138.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1053-_jpg.rf.098d668584634245751262443ab3705f.jpg
#
# 0: 640x640 1 person, 144.6ms
# Speed: 6.5ms preprocess, 144.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1054-_jpg.rf.2f3e04eac982a286b273c336b1528c04.jpg
#
# 0: 640x640 (no detections), 117.0ms
# Speed: 4.9ms preprocess, 117.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1056-_jpg.rf.58b04a22fac1d5416da768afe8b10239.jpg
#
# 0: 640x640 1 person, 1 cell phone, 128.1ms
# Speed: 6.2ms preprocess, 128.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1057-_jpg.rf.e0fc781a8f37f529d4d93182afc496d4.jpg
#
# 0: 640x640 1 person, 113.2ms
# Speed: 3.9ms preprocess, 113.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1058-_jpg.rf.0d8aabc7d6d3857f2ea11760ed77ba4a.jpg
#
# 0: 640x640 (no detections), 114.5ms
# Speed: 5.5ms preprocess, 114.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1060-_jpg.rf.46e7f9949b7a12d58e823fff80745764.jpg
#
# 0: 640x640 1 person, 2 cell phones, 115.0ms
# Speed: 4.1ms preprocess, 115.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1061-_jpg.rf.b7d479e3e31fa40a9ea98aceb5c03403.jpg
#
# 0: 640x640 1 person, 1 fire hydrant, 113.5ms
# Speed: 4.7ms preprocess, 113.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1062-_jpg.rf.3dd1cbeebb0a4fd5957b91ca4bca451c.jpg
#
# 0: 640x640 (no detections), 108.4ms
# Speed: 4.0ms preprocess, 108.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1063-_jpg.rf.8e25bcaaa7f1ed773c4d5aacb0cb16f9.jpg
#
# 0: 640x640 (no detections), 128.2ms
# Speed: 4.2ms preprocess, 128.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1064-_jpg.rf.2b7242b7778f784b0bafe5c071ab06e0.jpg
#
# 0: 640x640 1 person, 1 baseball bat, 144.3ms
# Speed: 5.2ms preprocess, 144.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1065-_jpg.rf.2de564532140ed0127c7e10e0454ea0a.jpg
#
# 0: 640x640 1 person, 1 cell phone, 142.8ms
# Speed: 4.4ms preprocess, 142.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1066-_jpg.rf.3ee4bbc980aa9d4032d46b964bdcede8.jpg
#
# 0: 640x640 1 person, 139.0ms
# Speed: 6.2ms preprocess, 139.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1067-_jpg.rf.0d04feb911a23cda35edf040c9d21d58.jpg
#
# 0: 640x640 (no detections), 150.4ms
# Speed: 5.2ms preprocess, 150.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1068-_jpg.rf.61388eed2149a951db47c2451b1874bc.jpg
#
# 0: 640x640 1 person, 110.0ms
# Speed: 4.3ms preprocess, 110.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1069-_jpg.rf.9be3a4116498f4ad83518b6927ece87f.jpg
#
# 0: 640x640 1 motorcycle, 133.3ms
# Speed: 5.8ms preprocess, 133.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1071-_jpg.rf.d1f2f7a5d04aa777a8ea05e16e954b63.jpg
#
# 0: 640x640 (no detections), 123.3ms
# Speed: 4.4ms preprocess, 123.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1072-_jpg.rf.3c30c5abf215b72fb1acc967082f092e.jpg
#
# 0: 640x640 (no detections), 116.8ms
# Speed: 4.4ms preprocess, 116.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1074-_jpg.rf.f883098f426c38db8b0f4bcaffe496d6.jpg
#
# 0: 640x640 (no detections), 132.6ms
# Speed: 4.7ms preprocess, 132.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1075-_jpg.rf.46a6887882d61891d17033b334b63888.jpg
#
# 0: 640x640 1 airplane, 1 train, 119.9ms
# Speed: 4.3ms preprocess, 119.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1076-_jpg.rf.2f4a64178f4716509e378413a292a17e.jpg
#
# 0: 640x640 1 person, 136.0ms
# Speed: 4.7ms preprocess, 136.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1077-_jpg.rf.abcc921427886d2735d29dff1831ab10.jpg
#
# 0: 640x640 1 person, 140.0ms
# Speed: 4.4ms preprocess, 140.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1078-_jpg.rf.1888121b7fb0083cbfc0de942304fe80.jpg
#
# 0: 640x640 1 person, 127.6ms
# Speed: 5.6ms preprocess, 127.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--108-_jpg.rf.9d3db0955a5868735ce5b7f85664b5af.jpg
#
# 0: 640x640 1 person, 133.1ms
# Speed: 5.1ms preprocess, 133.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1083-_jpg.rf.6848967daf5a876b469cfbfdf6f14fa4.jpg
#
# 0: 640x640 2 persons, 141.3ms
# Speed: 4.4ms preprocess, 141.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1084-_jpg.rf.ac852048b8e57829af5f741746a20138.jpg
#
# 0: 640x640 1 person, 1 tie, 128.7ms
# Speed: 5.4ms preprocess, 128.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1086-_jpg.rf.aa66e901177e4e865217b8ca7e461781.jpg
#
# 0: 640x640 1 person, 105.3ms
# Speed: 5.3ms preprocess, 105.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1087-_jpg.rf.fa20420270e273a2d5ba7f7ff4ff248f.jpg
#
# 0: 640x640 1 person, 1 book, 112.0ms
# Speed: 4.2ms preprocess, 112.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1088-_jpg.rf.f50976dc3d429298dd51843e5a45216d.jpg
#
# 0: 640x640 (no detections), 138.8ms
# Speed: 4.3ms preprocess, 138.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1089-_jpg.rf.295896cf863f8a6216538d3dfa6667f3.jpg
#
# 0: 640x640 1 person, 1 cell phone, 135.3ms
# Speed: 4.3ms preprocess, 135.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--109-_jpg.rf.d35ec19500c8ff57999ef1f7442062d8.jpg
#
# 0: 640x640 1 person, 123.9ms
# Speed: 6.9ms preprocess, 123.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1090-_jpg.rf.7fe7baf6f3437600c9f976cbe5d369e8.jpg
#
# 0: 640x640 1 person, 1 cell phone, 131.9ms
# Speed: 5.3ms preprocess, 131.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1091-_jpg.rf.811027a8af37434e74d6774a6fe2e647.jpg
#
# 0: 640x640 1 person, 159.6ms
# Speed: 4.6ms preprocess, 159.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1092-_jpg.rf.021bbd1a159ff59bde7e9e8413dd0e4f.jpg
#
# 0: 640x640 1 person, 134.2ms
# Speed: 5.3ms preprocess, 134.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1093-_jpg.rf.e2e2d4e22412d65c87018be1d3a9fc65.jpg
#
# 0: 640x640 (no detections), 122.5ms
# Speed: 4.6ms preprocess, 122.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1094-_jpg.rf.efee886b0a075bd3153d6aab039fa9ae.jpg
#
# 0: 640x640 3 persons, 127.7ms
# Speed: 6.4ms preprocess, 127.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1095-_jpg.rf.b58ac02d0f29e041848ffa311a5a3e4a.jpg
#
# 0: 640x640 2 persons, 1 bottle, 107.0ms
# Speed: 4.4ms preprocess, 107.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1096-_jpg.rf.01a08dced0669e3fcaaa85c9cdd85368.jpg
#
# 0: 640x640 1 person, 118.7ms
# Speed: 4.1ms preprocess, 118.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1097-_jpg.rf.0538bbbbaa97fb659e7759413b7dd055.jpg
#
# 0: 640x640 (no detections), 124.2ms
# Speed: 4.3ms preprocess, 124.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1098-_jpg.rf.36c0329ef3075fba86cd0c825d8c4426.jpg
#
# 0: 640x640 5 persons, 2 chairs, 149.7ms
# Speed: 4.6ms preprocess, 149.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1099-_jpg.rf.e399550419ef846202724ef95d6d02ad.jpg
#
# 0: 640x640 1 tv, 117.8ms
# Speed: 4.7ms preprocess, 117.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--110-_jpg.rf.ca7c52169a0363ddfce3f20ac7236416.jpg
#
# 0: 640x640 (no detections), 139.5ms
# Speed: 4.8ms preprocess, 139.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1100-_jpg.rf.ee125362bb95596218afd1faa2fa875b.jpg
#
# 0: 640x640 1 suitcase, 148.6ms
# Speed: 5.8ms preprocess, 148.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1101-_jpg.rf.9bfb928178d664427c25bb69c0839dea.jpg
#
# 0: 640x640 1 suitcase, 140.3ms
# Speed: 6.3ms preprocess, 140.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1102-_jpg.rf.f9e75580b55322ddb04076eed712de49.jpg
#
# 0: 640x640 2 persons, 128.0ms
# Speed: 6.0ms preprocess, 128.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1103-_jpg.rf.3a8eeb45d50213ffe6094139099966e6.jpg
#
# 0: 640x640 1 person, 116.3ms
# Speed: 4.7ms preprocess, 116.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1104-_jpg.rf.f61d58aeaff6b1c81ae6adced36b81ba.jpg
#
# 0: 640x640 (no detections), 132.9ms
# Speed: 4.2ms preprocess, 132.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1105-_jpg.rf.241e2850f031833a783121eaa327dc1c.jpg
#
# 0: 640x640 (no detections), 118.8ms
# Speed: 4.7ms preprocess, 118.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1106-_jpg.rf.fdb6405031a858b8360dfe15ed12122c.jpg
#
# 0: 640x640 (no detections), 127.6ms
# Speed: 4.2ms preprocess, 127.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1107-_jpg.rf.17dacaa4644d38d6234c27e1f74addee.jpg
#
# 0: 640x640 1 person, 2 cell phones, 116.0ms
# Speed: 8.7ms preprocess, 116.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1108-_jpg.rf.65bcae856ae2e36bfa10588ad1014b87.jpg
#
# 0: 640x640 1 person, 129.7ms
# Speed: 4.3ms preprocess, 129.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1109-_jpg.rf.dcf4c5fa6a1a6fa14a540b4529a88ff4.jpg
#
# 0: 640x640 2 persons, 151.9ms
# Speed: 4.4ms preprocess, 151.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--111-_jpg.rf.036eefe51a21326e681e06d049f4ab89.jpg
#
# 0: 640x640 1 truck, 134.9ms
# Speed: 4.3ms preprocess, 134.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1110-_jpg.rf.0bfc64ac617e3796ce59687cb42985bf.jpg
#
# 0: 640x640 1 person, 143.0ms
# Speed: 5.2ms preprocess, 143.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1111-_jpg.rf.a5183f462fd9c64768afbbb62b4b42ff.jpg
#
# 0: 640x640 3 persons, 1 suitcase, 1 cell phone, 126.6ms
# Speed: 5.3ms preprocess, 126.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1112-_jpg.rf.c51c7f262a197decf8299e93892761bc.jpg
#
# 0: 640x640 1 bird, 111.9ms
# Speed: 4.5ms preprocess, 111.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1113-_jpg.rf.854321c19c356b5a132e555878a7ce37.jpg
#
# 0: 640x640 1 person, 1 vase, 109.1ms
# Speed: 4.5ms preprocess, 109.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1114-_jpg.rf.31ef70358a4d32b6a0ff7e07d2110eac.jpg
#
# 0: 640x640 1 person, 114.2ms
# Speed: 4.4ms preprocess, 114.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1115-_jpg.rf.75b90698e370e9597d1ff0c278bc6c7a.jpg
#
# 0: 640x640 2 persons, 113.7ms
# Speed: 4.3ms preprocess, 113.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1116-_jpg.rf.75b6b0aeed05521a2e698253a6871d56.jpg
#
# 0: 640x640 1 person, 154.6ms
# Speed: 4.8ms preprocess, 154.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1117-_jpg.rf.847f4021dbd408375b83bef62df3e166.jpg
#
# 0: 640x640 1 person, 1 cell phone, 140.2ms
# Speed: 5.2ms preprocess, 140.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1118-_jpg.rf.822747298e61e608e1a7c545effeade3.jpg
#
# 0: 640x640 1 person, 1 kite, 154.2ms
# Speed: 4.7ms preprocess, 154.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1119-_jpg.rf.8ec1e8ddb3ef6663dcc7c65d9293cee2.jpg
#
# 0: 640x640 1 person, 1 kite, 146.2ms
# Speed: 5.1ms preprocess, 146.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--112-_jpg.rf.ebff7a20a8df0bd3c6929fb424bc43c7.jpg
#
# 0: 640x640 1 person, 117.5ms
# Speed: 4.6ms preprocess, 117.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing armas--1120-_jpg.rf.4ca349b658d3b3439820f697304db33a.jpg
#
# 0: 640x640 1 person, 1 kite, 109.5ms
# Speed: 4.9ms preprocess, 109.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# ...
#
# 0: 640x640 3 persons, 1 baseball bat, 206.0ms
# Speed: 6.6ms preprocess, 206.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1136_jpg.rf.6197d44c2d8aa80e95fe7fa13f579351.jpg
#
# 0: 640x640 1 person, 203.6ms
# Speed: 7.4ms preprocess, 203.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1137_jpg.rf.c38bed1113ff65b85ae6bba4d6736789.jpg
#
# 0: 640x640 1 person, 206.7ms
# Speed: 6.5ms preprocess, 206.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1138_jpg.rf.c88eb1664f02a2b7e73b65c23edbd17a.jpg
#
# 0: 640x640 1 person, 256.4ms
# Speed: 8.0ms preprocess, 256.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1139_jpg.rf.71a4ceeff4ba631fafc3f8e6048d43e5.jpg
#
# 0: 640x640 1 person, 208.9ms
# Speed: 7.4ms preprocess, 208.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_113_jpg.rf.5a0236a1e390348cd90f2407f7e17c3b.jpg
#
# 0: 640x640 2 persons, 201.5ms
# Speed: 6.9ms preprocess, 201.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1140_jpg.rf.08f6f4ab7d28d80c0bbb1d0cb53e74f1.jpg
#
# 0: 640x640 1 person, 201.0ms
# Speed: 7.2ms preprocess, 201.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1141_jpg.rf.09f79bdb23c1a81d8e497d6236495583.jpg
#
# 0: 640x640 2 persons, 201.5ms
# Speed: 6.8ms preprocess, 201.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1142_jpg.rf.62ecfd7de83f7539913ba93453b6728c.jpg
#
# 0: 640x640 2 persons, 247.4ms
# Speed: 6.5ms preprocess, 247.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1143_jpg.rf.017b73aefe653853c10d86c25bc78865.jpg
#
# 0: 640x640 1 person, 239.2ms
# Speed: 7.3ms preprocess, 239.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1144_jpg.rf.773e3e393cc2243c4fe3853e8ed75340.jpg
#
# 0: 640x640 1 person, 206.9ms
# Speed: 6.9ms preprocess, 206.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1145_jpg.rf.c6227d6fbcad5ef0bf3620e298951200.jpg
#
# 0: 640x640 1 person, 216.9ms
# Speed: 6.8ms preprocess, 216.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1146_jpg.rf.b856a79d5c65d1749086f70ebbc768e6.jpg
#
# 0: 640x640 1 person, 198.0ms
# Speed: 7.2ms preprocess, 198.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1147_jpg.rf.39c7ee2a981cec411f38f21f4701486c.jpg
#
# 0: 640x640 2 persons, 216.8ms
# Speed: 6.8ms preprocess, 216.8ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1148_jpg.rf.d7fad113d76bc4811edac2826409b389.jpg
#
# 0: 640x640 1 person, 263.5ms
# Speed: 7.0ms preprocess, 263.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1149_jpg.rf.54195a0c25097b43f6229ddb8560e79a.jpg
#
# 0: 640x640 1 person, 210.6ms
# Speed: 7.3ms preprocess, 210.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_114_jpg.rf.5f471fcfcab0c6e3d685c7de51979349.jpg
#
# 0: 640x640 2 persons, 1 knife, 206.9ms
# Speed: 6.7ms preprocess, 206.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.29)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\knife_114_jpg.rf.5f471fcfcab0c6e3d685c7de51979349.jpg
#
# 📂 Processing knife_1150_jpg.rf.62a7ae367ca4309987455fffd092929a.jpg
#
# 0: 640x640 2 persons, 1 baseball bat, 202.5ms
# Speed: 7.0ms preprocess, 202.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1151_jpg.rf.3a38b2ec024d766aa0ee2b46d2a6dd04.jpg
#
# 0: 640x640 1 person, 636.0ms
# Speed: 7.3ms preprocess, 636.0ms inference, 8.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1152_jpg.rf.6f579f921aa74af9c4f7bb77fb4b8c33.jpg
#
# 0: 640x640 1 person, 256.8ms
# Speed: 15.7ms preprocess, 256.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1153_jpg.rf.edf8d2f83ed0ba84c4a6d02fac059afd.jpg
#
# 0: 640x640 1 person, 203.9ms
# Speed: 7.0ms preprocess, 203.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1154_jpg.rf.88c74edbd0ad77bd91d59635769093b3.jpg
#
# 0: 640x640 1 person, 207.3ms
# Speed: 6.6ms preprocess, 207.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1155_jpg.rf.18281893bba17e214284de334e3b4b75.jpg
#
# 0: 640x640 2 persons, 235.4ms
# Speed: 6.7ms preprocess, 235.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1156_jpg.rf.f7b42a4c137a3072ea733fe2ffd0962b.jpg
#
# 0: 640x640 1 person, 221.4ms
# Speed: 6.9ms preprocess, 221.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1157_jpg.rf.d0084afe5fa27f3c0b20352762f2b432.jpg
#
# 0: 640x640 1 person, 206.3ms
# Speed: 7.0ms preprocess, 206.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1158_jpg.rf.bdb3fc05c7dec0f943daa3b5fb55d68b.jpg
#
# 0: 640x640 2 persons, 1 tie, 204.0ms
# Speed: 7.7ms preprocess, 204.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1159_jpg.rf.0fc289137868b6fd74a74a50a542fa0f.jpg
#
# 0: 640x640 (no detections), 209.5ms
# Speed: 6.5ms preprocess, 209.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_115_jpg.rf.14d4103490b7a66bfcd9a7cd92d1eb50.jpg
#
# 0: 640x640 1 person, 1 spoon, 250.3ms
# Speed: 7.4ms preprocess, 250.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1160_jpg.rf.37e0a6fed041c77b30609ec92dda27e1.jpg
#
# 0: 640x640 2 persons, 2 dining tables, 1 book, 3 clocks, 225.0ms
# Speed: 8.5ms preprocess, 225.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1161_jpg.rf.0150be3c7fefecefedb389dc12a81c69.jpg
#
# 0: 640x640 1 person, 200.4ms
# Speed: 6.8ms preprocess, 200.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1162_jpg.rf.36b1ed20d648605e4cbf161a2f55374e.jpg
#
# 0: 640x640 1 person, 1 knife, 209.2ms
# Speed: 6.7ms preprocess, 209.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.39)
# ✅ Saved annotated image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\knife_1162_jpg.rf.36b1ed20d648605e4cbf161a2f55374e.jpg
#
# 📂 Processing knife_1163_jpg.rf.ac87e781c77df81838f1dd75750952a3.jpg
#
# 0: 640x640 2 persons, 1 bed, 1 dining table, 1 book, 2 clocks, 215.5ms
# Speed: 7.0ms preprocess, 215.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1164_jpg.rf.b338c773c2213b22a07075825303ac12.jpg
#
# 0: 640x640 2 persons, 1 dining table, 1 clock, 223.9ms
# Speed: 6.9ms preprocess, 223.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1165_jpg.rf.d2d9dd9b33b5c1cd2b19511730ad9c40.jpg
#
# 0: 640x640 1 person, 249.7ms
# Speed: 7.4ms preprocess, 249.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1166_jpg.rf.8e5aaff9ce4cc072df1d6e9c2949b800.jpg
#
# 0: 640x640 2 persons, 1 dining table, 1 book, 3 clocks, 202.5ms
# Speed: 6.8ms preprocess, 202.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1167_jpg.rf.519a479a7a8c511b7fa5aabd0e5ccf66.jpg
#
# 0: 640x640 2 persons, 1 skateboard, 214.9ms
# Speed: 6.9ms preprocess, 214.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1168_jpg.rf.74d63a3dedc6a7bc465ec46d4b42394b.jpg
#
# 0: 640x640 2 persons, 1 cat, 1 dining table, 2 clocks, 203.8ms
# Speed: 7.0ms preprocess, 203.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1169_jpg.rf.e89d04848bcca2b5495f26ca43087257.jpg
#
# 0: 640x640 2 persons, 2 dining tables, 1 book, 2 clocks, 210.9ms
# Speed: 6.8ms preprocess, 210.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_116_jpg.rf.0dbd7e88a50bb16c5db4bdc6b783798a.jpg
#
# 0: 640x640 1 person, 257.2ms
# Speed: 7.4ms preprocess, 257.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1170_jpg.rf.cf1ca0cd80f14b3aac46946e53c24763.jpg
#
# 0: 640x640 1 person, 204.7ms
# Speed: 6.7ms preprocess, 204.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1171_jpg.rf.19961c7ed30abbe4bee295ec9f4f9863.jpg
#
# 0: 640x640 2 persons, 1 dining table, 204.9ms
# Speed: 6.9ms preprocess, 204.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1172_jpg.rf.e9c341911caf2cecfdd8d9951a29a561.jpg
#
# 0: 640x640 2 persons, 1 dining table, 3 clocks, 201.7ms
# Speed: 7.4ms preprocess, 201.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1173_jpg.rf.eb4c23aa3df5e00a8240e3b7275a1168.jpg
#
# 0: 640x640 1 book, 200.6ms
# Speed: 6.6ms preprocess, 200.6ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1174_jpg.rf.55944330c722c167cc54caa4d7db6691.jpg
#
# 0: 640x640 2 persons, 1 dining table, 1 book, 2 clocks, 290.4ms
# Speed: 6.8ms preprocess, 290.4ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1175_jpg.rf.47428d4e2ff816b19b1d30e9e624e5d3.jpg
#
# 0: 640x640 2 persons, 1 cup, 2 dining tables, 3 clocks, 200.2ms
# Speed: 6.8ms preprocess, 200.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1176_jpg.rf.47306c2be2be66cbd36a2d04e71d35d4.jpg
#
# 0: 640x640 2 persons, 1 dining table, 2 clocks, 196.4ms
# Speed: 6.7ms preprocess, 196.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1177_jpg.rf.ae9202a83282db103b22a3d78e7abd54.jpg
#
# 0: 640x640 2 persons, 202.3ms
# Speed: 7.1ms preprocess, 202.3ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1178_jpg.rf.7b2ca643e9113c9c7f10eea7b6b1ea0b.jpg
#
# 0: 640x640 2 persons, 1 dining table, 1 book, 3 clocks, 210.2ms
# Speed: 7.0ms preprocess, 210.2ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1179_jpg.rf.c2dcd5378fa8eb9f67d3151b08b48f2b.jpg
#
# 0: 640x640 2 persons, 1 bed, 2 dining tables, 1 book, 3 clocks, 229.5ms
# Speed: 6.7ms preprocess, 229.5ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_117_jpg.rf.a89bdd09553acc682b27fa155a641d50.jpg
#
# 0: 640x640 1 person, 236.4ms
# Speed: 6.9ms preprocess, 236.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1180_jpg.rf.9dfd65bd21391e8bc4ce993dc3c2a81b.jpg
#
# 0: 640x640 2 persons, 1 cup, 2 dining tables, 3 clocks, 201.6ms
# Speed: 6.6ms preprocess, 201.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1181_jpg.rf.16d3bfd2b132efed956aa0298c1ad4cd.jpg
#
# 0: 640x640 1 person, 200.8ms
# Speed: 7.3ms preprocess, 200.8ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1182_jpg.rf.5ff59ed240ca391a80c6c4e56231ab72.jpg
#
# 0: 640x640 2 persons, 2 dining tables, 2 clocks, 216.9ms
# Speed: 6.8ms preprocess, 216.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1183_jpg.rf.715d8a79d798a7ae68f9482c77a54fa7.jpg
#
# 0: 640x640 2 persons, 1 handbag, 2 dining tables, 2 clocks, 217.2ms
# Speed: 6.6ms preprocess, 217.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1184_jpg.rf.b488856da8bfbce7afb55eadad2fd840.jpg
#
# 0: 640x640 2 persons, 1 dining table, 1 book, 2 clocks, 243.4ms
# Speed: 7.5ms preprocess, 243.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1185_jpg.rf.365de8e5cd12d8137e69da8ac9a659ae.jpg
#
# 0: 640x640 2 persons, 2 dining tables, 2 clocks, 206.5ms
# Speed: 7.2ms preprocess, 206.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1186_jpg.rf.2deeaaf31698117cee4760786bd49633.jpg
#
# 0: 640x640 2 persons, 2 dining tables, 3 clocks, 199.2ms
# Speed: 6.6ms preprocess, 199.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1187_jpg.rf.2ad5c7f2f4cd879f34dda1b4fe2f75ed.jpg
#
# 0: 640x640 2 persons, 2 dining tables, 2 clocks, 203.4ms
# Speed: 6.5ms preprocess, 203.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1188_jpg.rf.149a33e032a6f5576863899b0fb25b23.jpg
#
# 0: 640x640 2 persons, 1 bottle, 1 dining table, 2 clocks, 216.1ms
# Speed: 6.3ms preprocess, 216.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1189_jpg.rf.0c541fd985137137eac981c8edb5a453.jpg
#
# 0: 640x640 2 persons, 1 bed, 1 dining table, 1 book, 2 clocks, 253.6ms
# Speed: 9.1ms preprocess, 253.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_118_jpg.rf.fc19d729ab66be516909c73b7333f2ba.jpg
#
# 0: 640x640 1 apple, 1 toothbrush, 203.3ms
# Speed: 6.9ms preprocess, 203.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1190_jpg.rf.c0618165b9257688da0877abcc95598c.jpg
#
# 0: 640x640 2 persons, 1 dining table, 1 book, 3 clocks, 197.8ms
# Speed: 6.7ms preprocess, 197.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1191_jpg.rf.7aa88f7a15274925449615cd1d055395.jpg
#
# 0: 640x640 1 person, 196.8ms
# Speed: 6.4ms preprocess, 196.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1192_jpg.rf.ea2fcfad7db72964ef30f11717f3e5e5.jpg
#
# 0: 640x640 2 persons, 2 clocks, 212.1ms
# Speed: 7.1ms preprocess, 212.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1193_jpg.rf.823ef28972c733aab12d87422d51c32e.jpg
#
# 0: 640x640 2 persons, 2 dining tables, 2 clocks, 287.9ms
# Speed: 7.0ms preprocess, 287.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# No expected objects found.
#
# 📂 Processing knife_1194_jpg.rf.26004bf2f1d4ba12c654ebb7827753e1.jpg
#
# 0: 640x640 1 person, 210.7ms

# %% [markdown]
# W

# %%
# object_detection.py

import os
from PIL import Image
import numpy as np
import cv2
import shutil
from ultralytics import YOLO

# === Load YOLOv8 Pretrained Model ===
yolo_model = YOLO('yolov8x.pt')  # You can upgrade to yolov8s/m/x if needed

# === Load Any Image Format (GIF-safe) ===
def load_image_any_format(img_path):
    img_pil = Image.open(img_path)
    if img_pil.format == 'GIF':
        img_pil.seek(0)
    img_pil = img_pil.convert('RGB')
    img_np = np.array(img_pil)
    return cv2.cvtColor(img_np, cv2.COLOR_RGB2BGR)

# === Run Detection and Copy Original on Match ===
def detect_objects_and_copy(img_path, expected_objects, output_dir):
    image = load_image_any_format(img_path)
    results = yolo_model(image)

    expected_objects = [obj.lower() for obj in expected_objects]
    match_found = False

    for result in results:
        for box in result.boxes:
            cls_id = int(box.cls[0])
            conf = float(box.conf[0])
            label = yolo_model.names[cls_id].lower()

            if label in expected_objects:
                print(f"[MATCHED] {label} ({conf:.2f})")
                match_found = True

    if match_found:
        os.makedirs(output_dir, exist_ok=True)
        dest_path = os.path.join(output_dir, os.path.basename(img_path))
        shutil.copy2(img_path, dest_path)
        print(f"✅ Copied original image to {dest_path}")

# === Batch Detection Runner ===
def detect_in_folder(folder_path, output_folder="./matches", expected_objects=None):
    supported_exts = (".jpg", ".jpeg", ".png", ".bmp", ".tiff", ".gif")
    if expected_objects is None or len(expected_objects) == 0:
        print("⚠️ You must specify a list of expected objects (e.g., ['knife', 'gun'])")
        return

    for img_name in os.listdir(folder_path):
        if img_name.lower().endswith(supported_exts):
            img_path = os.path.join(folder_path, img_name)
            print(f"\n📂 Processing {img_name}")
            detect_objects_and_copy(img_path, expected_objects, output_folder)

# === Main Runner ===

image_folder = r"C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\raw"
output_folder = r"C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections"
expected_objects = ["knife"]  # You can modify this

detect_in_folder(image_folder, output_folder=output_folder, expected_objects=expected_objects)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8x.pt to 'yolov8x.pt'...
# 100%|██████████| 131M/131M [00:08<00:00, 15.4MB/s]
# 📂 Processing 445_jpg.rf.2e04379013684f454abbc00564910fcc.jpg
#
# 0: 640x640 1 scissors, 1099.7ms
# Speed: 6.3ms preprocess, 1099.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00154_jpg.rf.d56723a3de6d775966551d0d0e8add67.jpg
#
# 0: 640x640 1 person, 1 tie, 1 potted plant, 1 cell phone, 1122.1ms
# Speed: 4.2ms preprocess, 1122.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00160_jpg.rf.23c17f2cfeacd7873e38995e4832e0c1.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1071.2ms
# Speed: 4.0ms preprocess, 1071.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00166_jpg.rf.d0f4052c7acfd9a298f657d3c56279e3.jpg
#
# 0: 640x640 1 person, 1078.4ms
# Speed: 4.5ms preprocess, 1078.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00169_jpg.rf.0a602b61133774dd78c98b0031ac834a.jpg
#
# 0: 640x640 1 person, 1058.0ms
# Speed: 4.1ms preprocess, 1058.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00190_jpg.rf.2ced39a08320a9db30ec44375062a1b8.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1078.8ms
# Speed: 4.1ms preprocess, 1078.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00235_jpg.rf.cdc8544dcec688136230ff2a24b14950.jpg
#
# 0: 640x640 1 person, 1085.5ms
# Speed: 4.4ms preprocess, 1085.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00265_jpg.rf.0488bc6053bb8bf3a55300c7caf4d269.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1061.8ms
# Speed: 4.0ms preprocess, 1061.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00271_jpg.rf.4ea36beb75644e4e876b60176934f9b2.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1 cell phone, 1060.6ms
# Speed: 5.8ms preprocess, 1060.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00274_jpg.rf.76e7b5de2b7a3d2cc14e374d935ebc99.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1053.8ms
# Speed: 4.4ms preprocess, 1053.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00277_jpg.rf.1b722bd1914427b42b9579722538945d.jpg
#
# 0: 640x640 1 person, 1 remote, 1073.6ms
# Speed: 4.1ms preprocess, 1073.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00280_jpg.rf.59ffd703fab71ff078f7efffb1b6d8b7.jpg
#
# 0: 640x640 1 person, 1055.9ms
# Speed: 4.6ms preprocess, 1055.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00283_jpg.rf.ec08f566106f2c1aff60a6ef0fa4b3ca.jpg
#
# 0: 640x640 1 person, 1 couch, 1 potted plant, 1085.5ms
# Speed: 3.9ms preprocess, 1085.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00286_jpg.rf.b0ff300d2647eefad04c3f85da899c55.jpg
#
# 0: 640x640 1 person, 1081.3ms
# Speed: 3.9ms preprocess, 1081.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00292_jpg.rf.46ef81c4bad3ec0bd519351bc429dc86.jpg
#
# 0: 640x640 1 person, 1 tennis racket, 1094.3ms
# Speed: 4.2ms preprocess, 1094.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00295_jpg.rf.4d6f38ca50209db652317ac7898e9e12.jpg
#
# 0: 640x640 1 person, 1088.8ms
# Speed: 4.2ms preprocess, 1088.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00298_jpg.rf.90347ebc304e4d673c568b1ac19d53ce.jpg
#
# 0: 640x640 1 person, 1045.2ms
# Speed: 4.3ms preprocess, 1045.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00301_jpg.rf.c5edc5525d1ae57b6d94652da47341d5.jpg
#
# 0: 640x640 1 person, 1064.4ms
# Speed: 4.2ms preprocess, 1064.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00304_jpg.rf.8d7d47c68f2f8485978b4c4e453f0b87.jpg
#
# 0: 640x640 1 person, 1070.6ms
# Speed: 5.0ms preprocess, 1070.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00313_jpg.rf.bc647384bbc01e9d619f3f5f476e1b99.jpg
#
# 0: 640x640 1 person, 1 remote, 1061.7ms
# Speed: 4.0ms preprocess, 1061.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00316_jpg.rf.86e3ad092aaf7bad1dea214f2fb8524b.jpg
#
# 0: 640x640 1 person, 1 remote, 1078.2ms
# Speed: 4.8ms preprocess, 1078.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00319_jpg.rf.75e92bfc8e81051765007adb8e8d708c.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1091.3ms
# Speed: 4.1ms preprocess, 1091.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00328_jpg.rf.adbdd789345a93f30c1bf7edb87e98cc.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1064.3ms
# Speed: 4.1ms preprocess, 1064.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00346_jpg.rf.b1e1cd89fe61387de53353ff49002c35.jpg
#
# 0: 640x640 1 person, 1033.8ms
# Speed: 4.4ms preprocess, 1033.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00349_jpg.rf.911aaca88c359d582c6b9c0bc183cd74.jpg
#
# 0: 640x640 1 person, 1 remote, 1070.3ms
# Speed: 4.2ms preprocess, 1070.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00370_jpg.rf.d1b3040ed3bdee0eed3bba9faafcd1f1.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1063.4ms
# Speed: 5.0ms preprocess, 1063.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00421_jpg.rf.b7ac40695cd7a034212f3a0556441f28.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1081.8ms
# Speed: 4.2ms preprocess, 1081.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00430_jpg.rf.96d982419a6d9599251ac97550753706.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1070.7ms
# Speed: 4.0ms preprocess, 1070.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABbframe00457_jpg.rf.13a55678a98891aae40e7f4006ff799f.jpg
#
# 0: 640x640 1 person, 1 tie, 1063.9ms
# Speed: 4.3ms preprocess, 1063.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00127_jpg.rf.f39cfc80859ccf4dcc3c62ebcaf8979c.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1070.9ms
# Speed: 4.1ms preprocess, 1070.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00133_jpg.rf.676153028c27ccef56121d2b75b3ed63.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1085.5ms
# Speed: 5.5ms preprocess, 1085.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00142_jpg.rf.176131dcbaecbe32c5dd55ccd05fd920.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1 cell phone, 1063.6ms
# Speed: 4.6ms preprocess, 1063.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00157_jpg.rf.1024ee338c34975dc3ec9405ab9da2b3.jpg
#
# 0: 640x640 1 person, 1 knife, 1 potted plant, 1064.6ms
# Speed: 4.0ms preprocess, 1064.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.34)
# ✅ Copied original image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\ABmframe00157_jpg.rf.1024ee338c34975dc3ec9405ab9da2b3.jpg
#
# 📂 Processing ABmframe00163_jpg.rf.b35eaad94e13cec3058200f89817c0f8.jpg
#
# 0: 640x640 1 person, 1083.3ms
# Speed: 6.5ms preprocess, 1083.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00172_jpg.rf.99dd984a71c916268089390669bca4dd.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1072.3ms
# Speed: 5.2ms preprocess, 1072.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00211_jpg.rf.596352d23c2bd937e2a26c56ff084a04.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1069.6ms
# Speed: 4.2ms preprocess, 1069.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00226_jpg.rf.e824fe8c2d23f8443bfe36490b8374b6.jpg
#
# 0: 640x640 1 person, 1101.8ms
# Speed: 4.6ms preprocess, 1101.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00271_jpg.rf.919066733ac88fa1ea6442730548bb24.jpg
#
# 0: 640x640 1 person, 1 remote, 1077.7ms
# Speed: 4.3ms preprocess, 1077.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00277_jpg.rf.c687fcf6cd0a0d34490716d22b6dd51a.jpg
#
# 0: 640x640 1 person, 1060.1ms
# Speed: 4.0ms preprocess, 1060.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00289_jpg.rf.6b5c700d51f5a0680a26562cc7e9e967.jpg
#
# 0: 640x640 1 person, 1 couch, 1121.3ms
# Speed: 4.0ms preprocess, 1121.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00301_jpg.rf.f009b0e538d00c922686bb8df2d069a8.jpg
#
# 0: 640x640 1 person, 1 remote, 1066.2ms
# Speed: 4.0ms preprocess, 1066.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00313_jpg.rf.92cc70f2b90904698cdaa18cd2b57477.jpg
#
# 0: 640x640 1 person, 1059.0ms
# Speed: 4.0ms preprocess, 1059.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00322_jpg.rf.4edc65002cbb165123c1c23b2b4e09f1.jpg
#
# 0: 640x640 1 person, 1056.6ms
# Speed: 4.3ms preprocess, 1056.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABmframe00412_jpg.rf.e3e666912cd88c3404e2f1962b6bcfea.jpg
#
# 0: 640x640 1 person, 1047.5ms
# Speed: 4.5ms preprocess, 1047.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00001_jpg.rf.36233bbeeeb5ff0e07ecc51b0fd014e3.jpg
#
# 0: 640x640 1 person, 1069.2ms
# Speed: 4.1ms preprocess, 1069.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00004_jpg.rf.f6b27a83e417eeadd9ac33b13cd2e210.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1088.3ms
# Speed: 4.2ms preprocess, 1088.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00019_jpg.rf.452d8624f6d5a67b14393b30c1aa38a9.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1 cell phone, 1060.1ms
# Speed: 4.3ms preprocess, 1060.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00064_jpg.rf.4b4694ef1f2a98df47aaafa30b968ceb.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1 refrigerator, 1081.0ms
# Speed: 4.2ms preprocess, 1081.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00067_jpg.rf.75749d0609ebd6a2f594373431cef989.jpg
#
# 0: 640x640 1 person, 1074.2ms
# Speed: 4.2ms preprocess, 1074.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00094_jpg.rf.36dc799bd6eebe562f1ba45de15b5c64.jpg
#
# 0: 640x640 1 person, 1095.8ms
# Speed: 4.3ms preprocess, 1095.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00100_jpg.rf.2085458c3860ad6532f35445a53528b1.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1088.9ms
# Speed: 4.0ms preprocess, 1088.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00133_jpg.rf.d956777b775c8f8611785df232483bcb.jpg
#
# 0: 640x640 1 person, 1 remote, 1061.8ms
# Speed: 4.3ms preprocess, 1061.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00151_jpg.rf.34817e076edecd2185a5d978e303be51.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1 cell phone, 1074.4ms
# Speed: 4.1ms preprocess, 1074.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00184_jpg.rf.4febb442f35d5d6bdae226a43d884890.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1071.0ms
# Speed: 4.2ms preprocess, 1071.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00190_jpg.rf.56710cc8369d47891023209aa88abfc7.jpg
#
# 0: 640x640 1 person, 1 handbag, 1 potted plant, 1053.6ms
# Speed: 4.3ms preprocess, 1053.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00214_jpg.rf.ae6c1e7d4c8e474123569e8bfa08f701.jpg
#
# 0: 640x640 1 person, 1077.5ms
# Speed: 4.0ms preprocess, 1077.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00223_jpg.rf.2e0d55585fa7f395666315e4f0881550.jpg
#
# 0: 640x640 1 person, 1069.8ms
# Speed: 6.2ms preprocess, 1069.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00241_jpg.rf.d35565984e7b8c28f31b3664b3e79710.jpg
#
# 0: 640x640 1 person, 1075.0ms
# Speed: 4.7ms preprocess, 1075.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing ABsframe00256_jpg.rf.8812293daacb638e29c5ed7e96f26fee.jpg
#
# 0: 640x640 1 person, 1 potted plant, 1118.9ms
# Speed: 4.0ms preprocess, 1118.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--1-_jpg.rf.18279624db90b5e46a11a034a54df7e5.jpg
#
# 0: 640x640 2 scissorss, 1054.2ms
# Speed: 3.9ms preprocess, 1054.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--10-_jpg.rf.f513a900e55937e97e2125e57131295e.jpg
#
# 0: 640x640 1 person, 1116.3ms
# Speed: 4.4ms preprocess, 1116.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--13-_jpg.rf.4570c347952e4b717b7569d867cc10c8.jpg
#
# 0: 640x640 1 person, 1083.8ms
# Speed: 4.0ms preprocess, 1083.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--15-_jpg.rf.5d2b4a4f17fdb02def74577d4c9f9986.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1083.5ms
# Speed: 4.2ms preprocess, 1083.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--17-_jpg.rf.8a2cc54489a36b6b2364fdee53773eca.jpg
#
# 0: 640x640 1 person, 1082.2ms
# Speed: 4.1ms preprocess, 1082.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--18-_jpg.rf.00ff11ce0cae2a7b1b95f2a31f475219.jpg
#
# 0: 640x640 1 person, 1 remote, 1089.7ms
# Speed: 4.1ms preprocess, 1089.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--19-_jpg.rf.a48054ca78bcd173bece9721531f5af0.jpg
#
# 0: 640x640 1 person, 1137.6ms
# Speed: 4.1ms preprocess, 1137.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--2-_jpg.rf.9051599c698dc36b62b3a698eb044f96.jpg
#
# 0: 640x640 1 person, 1 bottle, 1090.4ms
# Speed: 4.5ms preprocess, 1090.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--20-_jpg.rf.3abe66e1d869d04ffd38483b6df0d381.jpg
#
# 0: 640x640 1 person, 1070.5ms
# Speed: 4.1ms preprocess, 1070.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--21-_jpg.rf.671da2ab057c22df3adcf08d488c6558.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1043.3ms
# Speed: 4.3ms preprocess, 1043.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--22-_jpg.rf.49cdd8bf645d1127aa05bd3bd1561913.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1043.9ms
# Speed: 4.5ms preprocess, 1043.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--23-_jpg.rf.503e6fce622c195170291745d39208ad.jpg
#
# 0: 640x640 1 cell phone, 1081.8ms
# Speed: 4.3ms preprocess, 1081.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--24-_jpg.rf.c158efb15655f8a710564492726a27a1.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1068.9ms
# Speed: 4.4ms preprocess, 1068.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--25-_jpg.rf.2aacbd9b9e79fd936f34965b4f8edd29.jpg
#
# 0: 640x640 4 persons, 3 ties, 1065.4ms
# Speed: 4.9ms preprocess, 1065.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--26-_jpg.rf.a6d1812a55c2b2c733794fca0cd7153e.jpg
#
# 0: 640x640 2 persons, 1 cat, 1 cell phone, 1061.2ms
# Speed: 4.1ms preprocess, 1061.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--27-_jpg.rf.c84286e8e2d3b2a6a4319401a6fdf8fa.jpg
#
# 0: 640x640 1 person, 1072.3ms
# Speed: 5.2ms preprocess, 1072.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--28-_jpg.rf.ce986b789a4536b620aeee9b7b427bfa.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1067.0ms
# Speed: 4.0ms preprocess, 1067.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--29-_jpg.rf.d733b9a01b964214cd13517fcbd5c42e.jpg
#
# 0: 640x640 1 person, 1 frisbee, 1066.6ms
# Speed: 4.5ms preprocess, 1066.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--31-_jpg.rf.1a6b8f4ceab6ead774e04be9f30e5935.jpg
#
# 0: 640x640 1 person, 1064.0ms
# Speed: 4.2ms preprocess, 1064.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--32-_jpg.rf.d61310c05306394dbf832c0d2fda7bfb.jpg
#
# 0: 640x640 1 person, 1 frisbee, 1069.0ms
# Speed: 4.3ms preprocess, 1069.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--33-_jpg.rf.619d95c9a61ab01587d3573c5aa60543.jpg
#
# 0: 640x640 1 person, 1061.4ms
# Speed: 4.5ms preprocess, 1061.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--34-_jpg.rf.3e21f24e51f9d7e408dec2ae07994255.jpg
#
# 0: 640x640 1 person, 1059.2ms
# Speed: 4.0ms preprocess, 1059.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--35-_jpg.rf.6cb2c9b008bbdba2443077709b3f1aeb.jpg
#
# 0: 640x640 1 person, 1090.0ms
# Speed: 4.4ms preprocess, 1090.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--36-_jpg.rf.d629f1f82496a9206d4affe89f1058ff.jpg
#
# 0: 640x640 1 person, 1061.7ms
# Speed: 4.2ms preprocess, 1061.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--37-_jpg.rf.082774a655432e60fdcb01933ba5e81c.jpg
#
# 0: 640x640 1 person, 1035.6ms
# Speed: 4.1ms preprocess, 1035.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--39-_jpg.rf.4fa5d538a1473151234790b5edd23ed6.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1082.3ms
# Speed: 4.4ms preprocess, 1082.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--4-_jpg.rf.ee171083f4df60a22572936232fb9248.jpg
#
# 0: 640x640 3 persons, 1 remote, 1 cell phone, 1079.9ms
# Speed: 4.2ms preprocess, 1079.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--40-_jpg.rf.75f9e73acadec5072fab66a6e9e1b126.jpg
#
# 0: 640x640 1 person, 1090.7ms
# Speed: 4.1ms preprocess, 1090.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--41-_jpg.rf.00ea945501d0ed581b33a357803385d0.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1082.1ms
# Speed: 4.0ms preprocess, 1082.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--42-_jpg.rf.e5259681586a52e99458f9b77acf5c79.jpg
#
# 0: 640x640 1 person, 1067.2ms
# Speed: 4.0ms preprocess, 1067.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--43-_jpg.rf.3c9fba6de9aae1ad41b8ac2dddb116b1.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1276.5ms
# Speed: 4.2ms preprocess, 1276.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--44-_jpg.rf.9f20618b449f60e9652043c300022d3f.jpg
#
# 0: 640x640 1 person, 1067.3ms
# Speed: 3.9ms preprocess, 1067.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--47-_jpg.rf.ebc47ea75b0cc6d85f35f67d84569fe5.jpg
#
# 0: 640x640 1 person, 2 cell phones, 1092.7ms
# Speed: 4.2ms preprocess, 1092.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--48-_jpg.rf.779c8a9fb47afa9a7e1f193ada4aab6d.jpg
#
# 0: 640x640 (no detections), 1256.9ms
# Speed: 4.9ms preprocess, 1256.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--49-_jpg.rf.f6ce09faf8112526131507b0731ced36.jpg
#
# 0: 640x640 (no detections), 1076.9ms
# Speed: 4.8ms preprocess, 1076.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--5-_jpg.rf.670d1d036c70824abc48e6662362c7a8.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1057.7ms
# Speed: 4.3ms preprocess, 1057.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--50-_jpg.rf.b06fa330fbff7dd8a74517f5801dd6b1.jpg
#
# 0: 640x640 1 person, 1040.6ms
# Speed: 4.2ms preprocess, 1040.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--51-_jpg.rf.881a9b22374f4446c1b09f43de893592.jpg
#
# 0: 640x640 1 person, 1069.4ms
# Speed: 3.9ms preprocess, 1069.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--53-_jpg.rf.2f19089f3d2d350a717f80f185aec1c6.jpg
#
# 0: 640x640 (no detections), 1048.6ms
# Speed: 4.7ms preprocess, 1048.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--54-_jpg.rf.d8792d82b2cc63be8b97b5fb9f77239d.jpg
#
# 0: 640x640 1 person, 1061.9ms
# Speed: 4.0ms preprocess, 1061.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--55-_jpg.rf.00e335a88d49fe369a8aa640dec8ba96.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1046.8ms
# Speed: 4.1ms preprocess, 1046.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--57-_jpg.rf.36b1abb164ba8d909a271ba8f5f61afd.jpg
#
# 0: 640x640 2 persons, 1 cell phone, 1059.1ms
# Speed: 4.0ms preprocess, 1059.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--58-_jpg.rf.f2d4f9ed437f9817cf5219ac3dec5859.jpg
#
# 0: 640x640 (no detections), 1049.5ms
# Speed: 3.9ms preprocess, 1049.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--59-_jpg.rf.fe6133c356759ca83a43d74a4dca4140.jpg
#
# 0: 640x640 1 person, 1059.5ms
# Speed: 4.0ms preprocess, 1059.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--6-_jpg.rf.aa762726fe3a0f3543e9f07fe848e0aa.jpg
#
# 0: 640x640 1 suitcase, 1065.8ms
# Speed: 3.9ms preprocess, 1065.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--61-_jpg.rf.fdf0394a5448bc5d1113c4063e1338a9.jpg
#
# 0: 640x640 1 person, 1066.7ms
# Speed: 4.2ms preprocess, 1066.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--62-_jpg.rf.30325e55a28dca7c43a4c2321593e18f.jpg
#
# 0: 640x640 (no detections), 1060.8ms
# Speed: 4.0ms preprocess, 1060.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--63-_jpg.rf.a841c072cfa5de264f38e6b10d277106.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1120.0ms
# Speed: 4.3ms preprocess, 1120.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing armas--64-_jpg.rf.8c71dcc67c9d5180db308c8232441357.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1090.0ms
# Speed: 6.0ms preprocess, 1090.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_160_jpg.rf.41c7165e6776001da2b47866ee6cdd88.jpg
#
# 0: 640x640 1 person, 1 cell phone, 1068.6ms
# Speed: 4.2ms preprocess, 1068.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_161_jpg.rf.4b3cf6530bb46283bae12ae146cf62a4.jpg
#
# 0: 640x640 1 person, 1 scissors, 1102.3ms
# Speed: 4.1ms preprocess, 1102.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_163_jpg.rf.fe4ca068df4cdc83927e29e9184bb66b.jpg
#
# 0: 640x640 1 person, 1 remote, 1 scissors, 1074.1ms
# Speed: 4.2ms preprocess, 1074.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_167_jpg.rf.b14390b99839de05ad488442a5520365.jpg
#
# 0: 640x640 2 persons, 1 knife, 1082.2ms
# Speed: 4.0ms preprocess, 1082.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.88)
# ✅ Copied original image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\knife_167_jpg.rf.b14390b99839de05ad488442a5520365.jpg
#
# 📂 Processing knife_173_jpg.rf.f4e2dbe99d350e27bde394af3dabb415.jpg
#
# 0: 640x640 2 persons, 1092.0ms
# Speed: 4.4ms preprocess, 1092.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_182_jpg.rf.4f463af0f4d745de1559667c9dd07c1a.jpg
#
# 0: 640x640 1 person, 1 knife, 1 clock, 1 scissors, 1089.6ms
# Speed: 4.1ms preprocess, 1089.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.31)
# ✅ Copied original image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\knife_182_jpg.rf.4f463af0f4d745de1559667c9dd07c1a.jpg
#
# 📂 Processing knife_193_jpg.rf.106394cfcb84b88a9740d819173d795a.jpg
#
# 0: 640x640 1 person, 1 baseball bat, 1094.8ms
# Speed: 3.9ms preprocess, 1094.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_195_jpg.rf.57f26365b14fd5ee88ff286e280b3438.jpg
#
# 0: 640x640 1 person, 1 tie, 1079.2ms
# Speed: 4.0ms preprocess, 1079.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_196_jpg.rf.3dd2de74fce0606aba849a561def5479.jpg
#
# 0: 640x640 1 person, 1 toothbrush, 1065.7ms
# Speed: 4.0ms preprocess, 1065.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_221_jpg.rf.3b2c59967c14b9d4508d3ca90b677823.jpg
#
# 0: 640x640 1 person, 1 knife, 1076.7ms
# Speed: 4.0ms preprocess, 1076.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.87)
# ✅ Copied original image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\knife_221_jpg.rf.3b2c59967c14b9d4508d3ca90b677823.jpg
#
# 📂 Processing knife_227_jpg.rf.de1f020e98d188e9abe1ae49accba966.jpg
#
# 0: 640x640 3 persons, 1 scissors, 1114.0ms
# Speed: 4.0ms preprocess, 1114.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_231_jpg.rf.895856aaa69928c413009ba1210ac3c5.jpg
#
# 0: 640x640 1 person, 1 scissors, 1066.6ms
# Speed: 4.0ms preprocess, 1066.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 📂 Processing knife_235_jpg.rf.d2e873e84d9b64e4976098c98210ae09.jpg
#
# 0: 640x640 2 persons, 1 knife, 1078.2ms
# Speed: 4.1ms preprocess, 1078.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# [MATCHED] knife (0.32)
# ✅ Copied original image to C:\Users\scott\OneDrive\Documents\Protocols\Python\PyCharm\workspaces\pycharm_windows\AI_Projects\ai_cyberforensics\datasets\images\objects\detections\knife_235_jpg.rf.d2e873e84d9b64e4976098c98210ae09.jpg
